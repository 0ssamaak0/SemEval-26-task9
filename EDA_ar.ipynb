# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tqdm.auto import tqdm

# %% [markdown]
# # Basic EDA

# %%
# All subtasks using the same text data
train_df_1 = pd.read_csv("./dev_phase/subtask1/train/arb.csv")
train_df_2 = pd.read_csv("./dev_phase/subtask2/train/arb.csv")
train_df_3 = pd.read_csv("./dev_phase/subtask3/train/arb.csv")
dev_df = pd.read_csv("./dev_phase/subtask1/dev/arb.csv")

# %% [markdown]
# # Subtask 1

# %%
plt.hist(train_df_1["polarization"])
plt.show()

# %% [markdown]
# # Subtask 2

# %%
import itertools
import seaborn as sns

# List of label columns
label_cols = train_df_2.columns[2:]

# Prepare data for plotting
label_counts = train_df_2[label_cols].sum().sort_values(ascending=False)

num_labels_per_text = train_df_2[label_cols].sum(axis=1)
num_labels_value_counts = num_labels_per_text.value_counts().sort_index()

pair_counts = {}
for labels in train_df_2[label_cols].values:
    active = [label_cols[i] for i, v in enumerate(labels) if v]
    for pair in itertools.combinations(sorted(active), 2):
        pair_counts[pair] = pair_counts.get(pair, 0) + 1

pair_counts_sorted = sorted(pair_counts.items(), key=lambda x: x[1], reverse=True)
top_n = 10
top_pairs = pair_counts_sorted[:top_n]
pairs = [' & '.join(pair) for pair, _ in top_pairs]
counts = [count for _, count in top_pairs]

cooccurrence_matrix = np.zeros((len(label_cols), len(label_cols)), dtype=int)
for labels in train_df_2[label_cols].values:
    active_idx = [i for i, v in enumerate(labels) if v]
    for i in active_idx:
        for j in active_idx:
            cooccurrence_matrix[i, j] += 1

# 1. Label distribution (bar chart)
plt.figure(figsize=(6, 4))
label_counts.plot(kind='bar')
plt.title("Label Distribution (number of instances per label)")
plt.ylabel("Count")
plt.xlabel("Label")
plt.tight_layout()
plt.show()

# 2. Number of labels per text
plt.figure(figsize=(6, 4))
num_labels_value_counts.plot(kind='bar')
plt.title("Number of Labels per Text")
plt.xlabel("Number of Labels")
plt.ylabel("Number of Texts")
plt.tight_layout()
plt.show()

# 3. Most common label pairs (sorted)
plt.figure(figsize=(6, 4))
sns.barplot(x=counts, y=pairs, hue=pairs, palette="Blues_d", legend=False)
plt.title("Top 10 Most Common Label Pairs")
plt.xlabel("Count")
plt.ylabel("Label Pair")
plt.tight_layout()
plt.show()

# 4. Cooccurrence heatmap
plt.figure(figsize=(6, 5))
sns.heatmap(
    cooccurrence_matrix,
    xticklabels=label_cols,
    yticklabels=label_cols,
    annot=True,
    fmt='d',
    cmap='Blues'
)
plt.title("Cooccurrence Heatmap")
plt.xlabel("Label")
plt.ylabel("Label")
plt.tight_layout()
plt.show()

# %% [markdown]
# # Subtask 3

# %%
import itertools
import seaborn as sns

# List of label columns
label_cols = train_df_3.columns[2:]

# Prepare data for plotting
label_counts = train_df_3[label_cols].sum().sort_values(ascending=False)

num_labels_per_text = train_df_3[label_cols].sum(axis=1)
num_labels_value_counts = num_labels_per_text.value_counts().sort_index()

pair_counts = {}
for labels in train_df_3[label_cols].values:
    active = [label_cols[i] for i, v in enumerate(labels) if v]
    for pair in itertools.combinations(sorted(active), 2):
        pair_counts[pair] = pair_counts.get(pair, 0) + 1

pair_counts_sorted = sorted(pair_counts.items(), key=lambda x: x[1], reverse=True)
top_n = 10
top_pairs = pair_counts_sorted[:top_n]
pairs = [' & '.join(pair) for pair, _ in top_pairs]
counts = [count for _, count in top_pairs]

cooccurrence_matrix = np.zeros((len(label_cols), len(label_cols)), dtype=int)
for labels in train_df_3[label_cols].values:
    active_idx = [i for i, v in enumerate(labels) if v]
    for i in active_idx:
        for j in active_idx:
            cooccurrence_matrix[i, j] += 1

# 1. Label distribution (bar chart)
plt.figure(figsize=(6, 4))
label_counts.plot(kind='bar')
plt.title("Label Distribution (number of instances per label)")
plt.ylabel("Count")
plt.xlabel("Label")
plt.tight_layout()
plt.show()

# 2. Number of labels per text
plt.figure(figsize=(6, 4))
num_labels_value_counts.plot(kind='bar')
plt.title("Number of Labels per Text")
plt.xlabel("Number of Labels")
plt.ylabel("Number of Texts")
plt.tight_layout()
plt.show()

# 3. Most common label pairs (sorted)
plt.figure(figsize=(6, 4))
sns.barplot(x=counts, y=pairs, hue=pairs, palette="Blues_d", legend=False)
plt.title("Top 10 Most Common Label Pairs")
plt.xlabel("Count")
plt.ylabel("Label Pair")
plt.tight_layout()
plt.show()

# 4. Cooccurrence heatmap
plt.figure(figsize=(6, 5))
sns.heatmap(
    cooccurrence_matrix,
    xticklabels=label_cols,
    yticklabels=label_cols,
    annot=True,
    fmt='d',
    cmap='Blues'
)
plt.title("Cooccurrence Heatmap")
plt.xlabel("Label")
plt.ylabel("Label")
plt.tight_layout()
plt.show()

# %% [markdown]
# # Analysis of Arabic Texts

# %% [markdown]
# ## ALDi

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification
model_name = "AMR-KELEG/Sentence-ALDi-50"

tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSequenceClassification.from_pretrained(model_name)
device = "mps"
model.to(device)

def compute_aldi_score(sentence):
    inputs = tokenizer(sentence, return_tensors="pt")
    inputs.to(device)
    outputs = model(**inputs)
    logits = outputs.logits
    return min(max(0, logits[0][0].item()), 1)

texts = train_df_1["text"]
ALDi_scores = []

for text in tqdm(texts):
    ALDi_scores.append(compute_aldi_score(text))
# Out:
#   0%|          | 0/3380 [00:00<?, ?it/s]

# %%
train_df_1["ALDi_score"] = ALDi_scores
# Explore 10 examples with least ALDI (using index)
least_aldi_texts = texts.iloc[np.argsort(ALDi_scores)[:10]]

print("Texts with least ALDI scores:")
for i, text in enumerate(least_aldi_texts, 1):
    print(text)

print("-" * 50)
top_aldi_texts = texts.iloc[np.argsort(ALDi_scores)[-10:]]

print("Texts with highest ALDI scores:")
for i, text in enumerate(top_aldi_texts, 1):
    print(text)

print("-" * 50)
# Find 10 texts in the middle like (0.4-0.6), print text : score
ALDi_scores_np = np.array(ALDi_scores)
middle_mask = (ALDi_scores_np >= 0.4) & (ALDi_scores_np <= 0.6)
middle_indices = np.where(middle_mask)[10:30]
middle_aldi_texts = texts.iloc[middle_indices]
middle_aldi_scores = ALDi_scores_np[middle_indices]
for text, score in zip(middle_aldi_texts, middle_aldi_scores):
    print(f"Text: {text}\nScore: {score}\n")
    print("")
# Out:
# Texts with least ALDI scores:
# تغطية صحفية: طائرات الاحتلال تشن هجوما جوياً واسعاً على سوريا بالتزامن مع توغل بري بين محافظتي درعا والقنيطرة جنوب البلاد
# #أردوغان: دافعنا بشجاعة عن القضية الفلسطينية وأبناء #غزة الأبطال، وأينما وُجد اضطهاد أو صراع أو ظلم سنكون هناك لإنهائه
# الناطق العسكري باسم أنصار الله: قررنا استئناف حظر إبحار السفن الإسرائيلية بالبحرين الأحمر والعربي وباب المندب، ويستمر هذا الحظر حتى فتح معابر قطاع #غزة ودخول احتياجاته من غذاء ودواء
# الماسونية لا تعتبر منظمة تجارية، ولكن العديد من الماسونيين المشهورين كانوا رؤساء شركات أو مؤسسين لبعض الشركات البارزة
# تغليظ عقوبة ختان الإناث للسجن المشدد..وتطورات محاولة تعويم السفينة الجانحة..وهذا جدول تشغيل مترو الأنفاق خلال شهر رمضان
# رغم حظره بشكل رسمي في مصر عام 2008 إلا للضرورة الطبية، لا يزال ختان الإناث يمارس على نطاق واسع، وتتراوح عقوبته بين السجن ثلاثة أشهر وسنتين
# #السودان يصادق على قانون يجرّم #ختان_الإناث
# ختان الإناث يلحق أضرارا بأكثر من 230 مليون فتاة، ودعوة أممية للقضاء عليه
# اختطاف الحكومة الألمانية لأطفال من عائلة مسلمة ترفض تعليم أطفالها عن المثلية الجنسية.
# - مقترح ويتكوف يتضمن إدخال المساعدات الغذائية إلى غزة خلال فترة تمديد وقف إطلاق النار
# --------------------------------------------------
# Texts with highest ALDI scores:
# مادري مخبله وله مادري شسميهه الله يشفيهه
# اول مرة نسمع بهاد خيتي 😒😏 لي لقات فورمتها زينة تعريها وتقول انا مغنية و فنانة لعفن ولا ماشي الفن 👎👎👎
# هي إيه حكاية المسلسلات اللي فيها واحد بلطجي كل ما يتخانق مع حبيبته يهددها انه هيشوهها أو هيقتلها ويهينها عادي ونضحك هاهاها وهي تضحك وتدلع عليه أكتر ناقص يفتح في وشها مطوة! في إيه بس😅🤦🏻‍♀️
# امومه والضرب بالشبشب الطاير امومه والجري ورا العيال امومه واخد العيديه  منهم امومه🤣🤣🤣
# هذي مصممه انها محترمه هذا مجنونه رسمي ربي يقلعها شوهت البنات محترمات لما تضم حالها منهم المفروض هذي يوقفوها ايش الاحنطاط هذا
#     دي قمر في كل حاجة تعملها و ادوارها جميلة زيها هي مش ايتن يبقى قطعة سكر تتكلم
# عاوزين المجتمع يخرب اكتر ما هو خربان بفكركم المعادى للسنة والشريعة جاتكم القرف فى مناظركم
# والله برديس شكلها زي القرد اصلا وصوتها زي الرجاله وكلها علي بعضها تقرف
# هسه انتي شلونج يابقره اذا راغب هيج انتي شنو
# احلام  خلك من ذول كلهم و روحي عند طفاح يمطك
# --------------------------------------------------
# Text: احلام انتي ونعالي ومنو انتي حتى تقيمين الفنانين الملكه احلام هههههههه البقره احلام بابا عوفي الفن لااهل الفن
# Score: 0.8123910427093506
#
#
# Text: وره الكواليس تنيجج من وره بعير صطناعي على فكرة احﻻم رجل مو مره لهن تخيل على البنات الحلويات هههههههه
# Score: 0.9309240579605103
#
#
# Text: .خخخخ الملكه احلام فيها شذوذ شنو هل بوس والدلع مع شذا والله عيب اطلعت بويه احلام بس بشعر خخخخخخخ
# Score: 0.8854936957359314
#
#
# Text: الله يخزي احلام هي والبرنامج الخايس الي كله مصخره
# Score: 0.9593015313148499
#
#
# Text: كس ام احلام الي ماربتها وش ملكه هههه متستاهل ملكه حرام مفسخه جواده بنت كلب الله يدخله نار جهنم وال عياذ بالله
# Score: 0.8505613803863525
#
#
# Text: أول شي انتي تشبهين شغالتنا في البيت
#
# ثاني شي انتي ملكة جمال الإزباله
#
# 3 جميع الاسعودين أحلى منك انتي
# Score: 0.7219297885894775
#
#
# Text: احلام انا اجر على اهلك يبنت الزنا اللعن ابووكي
# Score: 0.36074525117874146
#
#
# Text: و الله كلهم عالم زبالة و احنا للاسف بنشجعهم عالم وسخة
# Score: 0.8565295338630676
#
#
# Text: خيرالكلام ما قل و دل %  جيب ( طز )   و شوية ( مرحبا )   اخلطهم في المولينكس تطلع ( احلام )
# Score: 0.6047813296318054
#
#
# Text: احلام .. شخصيه منحطه منحطه منحطه لأبعد الحدود .. و كلمة شرموطه قليله عليكي
# Score: 0.4272824227809906
#
#
# Text: والله ان شمس احلى منك ي اطقاقه ع اقل شمس احساس وجمال انتي لا احساس ولا جمال هيا اخررجي ي طقاقه 😂😂
# Score: 0.798751950263977
#
#
# Text: الوسط الفني وسط حثالة الا من تاب وتاب الله عليه نسأل الله لنا ولهم الهداية
# Score: 0.08891163021326065
#
#
# Text: والله يا احلام تبقين بعيني زباله مشتمع يا فاشله
# Score: 0.45431047677993774
#
#
# Text: بالله هاي فنانة مكانها بالزبل أصلا كل ثقافة فنية ما عندها لأ وفوكاه تقول اني ملكة انتي ملكة على الزبل يا زبالة
# Score: 0.8499293923377991
#
#
# Text: ابي اعرف من يضاجع الثاني احلام ولا مبارك جد اسال
# Score: 0.6421966552734375
#
#
# Text: ولك انت ساقط وحجيك تمظرط طط طط ط الك قد رك
# Score: 0.9792119860649109
#
#
# Text: أحلام أكلي عير ياوصخه ختفؤؤؤؤؤؤؤؤؤؤؤؤؤؤؤؤؤؤؤؤؤ عيربيج وبل أسلام أل أنتي بي دكومي عريضه حافضه ألقرأن وتقره ألقرأن وتغني ألعريضه بلعت ألعير صخله
# Score: 0.9206959009170532
#
#
# Text: احلام الكره العاهرة المطار دارسة شريعة  طاح حظك يا احىلام
# Score: 0.5192214250564575
#
#
# Text: مريضة نفسية مفتكرة حالها بشرية و شكلها غربي😂😂😂😂و تلبس تياب قد بنت بنتها 😂😂😂😂
# Score: 0.8017008900642395
#
#
# Text: شمس احسن منج يزربه مو متربيه انتي اعتقد ماتعرفين شنو التربيه
# Score: 0.9661908149719238
#
#
# Text: كس ام احلام على ام السوري لمعفن الي بتفلسف
# Score: 0.9682309031486511
#
#
# Text: شواز يعني حذاء فالحذاء على راسج وراس زوجك الخنيث
# Score: 0.39793404936790466
#
#
# Text: امداج ومدة زوجاك الخنيذ الكواد الساقط ياخيسة ام العيوارة  ام كس الخيس
# Score: 0.5352639555931091
#
#
# Text: هوانتي مطية وبهيمة وكالبة ونانية وتحب بس نفسة  تحب القران  هوانتي كاولية وغجرية امداج ومدة اهلج السقطين ياحيوانة ابن العراق وبس
# Score: 0.519719123840332
#
#
# Text: كيف متخرجه من علوم شرعيه وتقول رقاصه وتسب لعن الله ابو من شهرها هاذي عار على الخليج بنت الكلب
# Score: 0.9319670796394348
#
#
# Text: هذه  احلام مثل البقره اصلا هاذه تغتصب النساء باصبعها
# Score: 0.2676413059234619
#
#
# Text: مين عم يقول الdislikeأكتر؟؟؟ههههه
# ياحبيبي طلعت شاذة كمان هاد الناقص
# يلعن شكلك بومة مسخرة بس يلعن أبو المصاري
# تضربي بس شوفك بستفرغ
# Score: 0.9282137751579285
#
#
# Text: شوف نانسي شلون ناسكة وناشفة وشوف هاي الهايشة ماتعرف حته تحجي ياخي صدك قهر انتي مراة وهاية مراة
# Score: 1.0
#
#
# Text: هو لازم هل زبالة تنلم لكن قالة كلمة صحيخة ليش ما ينقبض على هيفاء وهبي وغيرها ؟،؟؟؟؟؟؟ولا لانهم ماسونياات
# Score: 0.9853401780128479
#
#
# Text: المره عارفه افلام  الثقافة .احييييييي ...وجايه  تعدل  علي برديس هههههههه
# Score: 1.0
#
#
# Text: برديس عاهرة و ربنا يخلصن من امثلك ولو ابوكي رجل كان زمانو  دفن العاهرة
# Score: 0.613261342048645
#
#
# Text: يعني ع اساس سعاد حسني الشرموطه والشراميط الي معاها كانو يبيعون مسابح بالحرم يعمي على زق وبرديس تاج راسكم
# Score: 0.8574548363685608
#
#
# Text: والله انا مش شايف غير ان برديس ده شرموطه ومبسوطه بقلة ادبها ومبسوطه بالنيك ده كنوع من الشهره وعايزه تزيط
# Score: 0.9614404439926147
#
#
# Text: احه كسمك يعني سعاد حسني كانت شيخه سعاد اعملت اوسخ من برديس مليون مره ....الفنانات كلهم عهر
# Score: 0.84268718957901
#
#
# Text: ايه الاجالك من كول واحد يهزقك يابنت ستين كلب ملقتيش راجل يلمك
# Score: 0.9605026841163635
#
#
# Text: يللا ياملفاية يابنت المتناكة يا لبوة انتي تستاهلى اكتر من كدة بكتير
# Score: 1.0
#
#
# Text: الكلب طوني خليفة علق عليها وناسي يعلق على ميريام وفيفي عبده
# Score: 0.23983322083950043
#
#
# Text: أي وحدة بتطلع تتعرى وترقص وتعمل كليبات إباحية إسجنوها وخلصونا منها.....بس للأسف الناس بتحب الاشكال الوسخة زي دي
# Score: 0.8761228322982788
#
#
# Text: مش عارف بتهاجمو برديس ليه
# ما البلد مليانه اوسسسخ منها
# سعاد حسني نفسها افلامها كلها بوس وخلع وعري
# Score: 0.9819661974906921
#
#
# Text: على اساس سعاد حسني كانت تدرس قرأن
# كل افلامها وسخه
# Score: 0.40154027938842773
#
#
# Text: الخضردولار ي هو الذي جعل من كبوس احلام ومن النهيق الحمير نتاع هذ الحمارة الي فن
# Score: 0.6204202771186829
#
#
# Text: الله يلعنك يا وسخة . انتي ملكة جمال الأبقار
# Score: 0.5508414506912231
#
#
# Text: بدك تاكلي خنزير موش كنطاكي يا افعى ياحلوف  وجه القرد
# Score: 0.9589490294456482
#
#
# Text: وش ملكه سلامااات تروها طقاقه ملعونه ابو ولا الوجه عقدها مع شركه انشأت علشان عمليه التجميل ياطقااااااقه
# Score: 1.0
#
#
# Text: انتي اصلان  شرموطه يا  احلام  ومشان هيك ما تعرفين الشرفاء
# Score: 0.9536581039428711
#
#
# Text: الله يشفيها محدثة نعمه…وهذا سبب انها متخبطه بكل شي اخلاقها صفر ومتناقضه اقول الله يرحم ايام الطاره مع امك وخالاتك تطلعوا العروس وتاكلوا فضلة المعازيم
# Score: 0.6080847978591919
#
#
# Text: ليش  بصلتكم محرووقه؟؟!!  KISS  اخت الاعلام ,  و كس  اخت احلام  معها  مصاري   وبتذل  الاعلام..
# Score: 0.9703691005706787
#
#
# Text: رجال الخليج يحبون اللواط والان نساء الخليج احلام she lesbian عالم عالم العاهرين والعاهرات
# Score: 0.08569357544183731
#
#
# Text: يلعن ابوكي المفروض محدش يديها أي انتباه لأن كده بتحسسوها ان هي بني آدمة
# Score: 0.9988383650779724
#
#
# Text: استغفر الله اعتقد ان احلام صناعة صينية وليست مخلوق لان الله عز وجل لم يخلق هذه الكائن الذي اسمه احلام
# Score: 0.0
#
#
# Text: انا برشح لهم الفنان عبدالله رويشد بدل هاي البقره
# Score: 0.7324482798576355
#
#
# Text: احلام خرا لعنة الله علی وجهها اللي مثل وجه القرد
# Score: 0.5844311118125916
#
#
# Text: الله يلعنك يا احلام الطكاكه .. ولك تتكلمين على صوت ذكرى ؟؟؟ والله الحمار والخنزير احسن منك يا احلام الخايسه
# Score: 0.5286939144134521
#
#
# Text: أول شغل عالم الفن بكل أنواعه وسخ ومنحط وقذر وتاني شي الأعلام أوسخ من عالم الفن وأحقر منه ولذلك الأثنان يساندون بعضهم
# Score: 0.7167980074882507
#
#
# Text: القافلة تسير والكلاب تنبح سير واللة معاك يا أحلام تحيه لكم من اليمن فنانه وغصبن عنكم
# Score: 0.41525542736053467
#
#
# Text: استغر الله لو تشوف وجهها وهي تدلع كذا مارح تسوي الحركات هذي الله يلعن هذي العجوز تدلع على كبر ارجوكم كفايه ياقنواتنا
# Score: 0.9550954699516296
#
#
# Text: اللبنانيين شراميط الفن العريق
# قبل ماتقول شي ياخنزير يالمستعمر من فرنسا شوف نفسك بالاول
# الخليجيين ديسلايك للفيديو
# Score: 0.8420302271842957
#
#
# Text: لك كس اخت يلي قال عنك مطربة.....تفووو عليك وسخة...
# Score: 0.880086362361908
#
#
# Text: فنانة العرب هههههههههههه والله ضحكتينى هاد غبيه ووقحه
# انا مابحبها اعود بالله هاد شيطانه
# Score: 0.7777343988418579
#
#
# Text: طكاكه مجردة من الاخلاق سوقية في كلامها وتربية سزز وهي ليست سوى غجرية
# Score: 0.4542917311191559
#
#
# Text: انت يلي رافع هذا المقطع خراي عليك وعلى الملكة احلام ههههه
# Score: 0.840894341468811
#
#
# Text: وصل بها أنها أصيبت بجنون البقر عفوا العظمه للكلب العظمه يخرب بيتج ضل حد ما تخانقتي معاه غبيييييييييييييييه
# Score: 0.5450026392936707
#
#
# Text: يخرب بيتك مزنخك
# بغله لو ضليتي بس تسمعينا الاغاني بصوتك كان اشرفلك
# بس وقد يلي بينتي ع حقيقتك بتقرررفي
# مريضه نفسيه
# اخ تفو
# Score: 0.9845086932182312
#
#
# Text: هاذيلا معزلة وخربو الفن بسلوبهم وشكالهم ولبسهم راح الفن وماعترف فيهم فنانين من راغب لين مقدمة البرنامج كلهم حثالة.
# Score: 0.9943819046020508
#
#
# Text: لما تذكروني بهذه الجرثومة اللي مرضت الفن ووسخت الفنانين. اه وردة الجزائرية وماجدة الرومي ووووواهاه
# Score: 0.4489874243736267
#
#
# Text: ايباخ امسية نفسج ملكة ونتي جكمة او جنج قرد
# Score: 0.9672930836677551
#
#
# Text: كس امك يا احلام وكس ام الفن الي اعترف فيك
# Score: 0.915745198726654
#
#
# Text: هي ملكة بس
# على
#  عرش
# قمة الحمير اللي يسمعوها
# ويكرم السامعين والمتابعين هنا
# بالردود
# Score: 0.5519023537635803
#
#
# Text: وهية احلام منيلهة صوت بس جوعر مثل الجاموسة ههههههههههههههههههههههههههه
# Score: 1.0
#
#
# Text: احلام بقره والله هبلا والنَّاس يضحكون عليها وماتحس وماتفهم
# Score: 0.9165412783622742
#
#
# Text: حبيبتي أحلام انتي تاج على رأس كل نجس يمسك بكلام مولئق فيكي ماعليكي منهم تره كلهم بيغارومنك حبيبتي أحلام اني.من العراق ومعجبه بيج
# Score: 0.7196774482727051
#
#
# Text: عبدة طقاقة
# الخرا كل ما حركتة فاحت ريحتة
# وأحلام خرا. .. يعني اعطيتوها أكبر من حجمها كويحه
# Score: 0.584597647190094
#
#
# Text: كس امك يا احلام الطقاقة ولك انتي وحدة شرموطة تمص القضيب من كنتي صغيرة وكل الخليج يعرف ولك  خلي زوجك الخنزير يلحس كسك الخايس
# Score: 0.8952839374542236
#
#
# Text: هاي مراهقة وتحس روحها مثل نانسي وباقي الفنانات الصغار الله ياخذج وياخذ امثالج يابكرة
# Score: 1.0
#
#
# Text: بيف باف قاتل الحشرات والصراصير ومنهم احلام جربو ولا احلام بعد اليوم.
# Score: 0.32832401990890503
#
#
# Text: سخيفه ومعتوه والشرهه على اللي خرجها من شرنقة الطقاقات
# Score: 0.59144526720047
#
#
# Text: غبيييييي هو والي جنبه قال بالتركي نمسا يعني نامو يااتافه بالتركي مافي ولا كلمة نمسا طبيعي تكون غبي لانك قاعد جنب مصدر الغباء
# Score: 0.7026497721672058
#
#
# Text: يا ناس انتو اللى عليكم الغلط. انا اول مرة اعرف ناس ادميين يسمعو لبقرة. او حمارة مثل احلام
# Score: 0.8888466954231262
#
#
# Text: من الزريبة الى الشهرة والمال فعمل تربنة فالمخ فتغير الشكل الخارجي وبقيت الوساخة والانحطاط
# Score: 0.13876084983348846
#
#
# Text: أحلام هي رجال أو أمرئة خرى عليكي وعلى يلي شافك وأنبسط لأنك زبالة ومجنونة تفوووو عليكي وعلى يلى نزلك في البرامج
# Score: 0.9945151209831238
#
#
# Text: متخلفة وجاهله وتصلح ان تكون  ملاكم وليس فناه ذو احساس مرهف وليست سوى نكرة فاشله مغرورة
# Score: 0.0
#
#
# Text: احلام غبية وسلوكة سياسي غبي وتفكيرها غبي وتصرفتها غبية وغناءها غبي  لما راح راغب خلص برنامج اصلا اشكال وسخة
# Score: 0.519443154335022
#
#
# Text: ما تشبعين من الكنتاكي يا بقرة همداج انتي وزوجج يا خنازبر
# Score: 0.9119179844856262
#
#
# Text: حمارة وغبية واللي خلاها تشارك في عرب ايدل هو الحمار الاكبر مغرورة وتافهة
# Score: 0.7917446494102478
#
#
# Text: فد وحدة حثاله وحرامات والبرنامج ما اتابعه لان بي احلام وحده قذره وحرامات تحكم على اصوات
# Score: 0.7658763527870178
#
#
# Text: هسه انتي شلونج يابقره اذا راغب هيج انتي شنو
# Score: 1.0
#
#
# Text: نام سه اجل 😝 سبحان من جمعكم بقرة وثور
# Score: 0.6449093818664551
#
#
# Text: اخلام لاتستطيع المشاركه لانهم كتبو لافته على الباب ممنوع دخول القرود
# Score: 0.05373571068048477
#
#
# Text: تفووو عليك ياللي مسوي الفديو مووت قهر ماتوصولون ربع احﻻم
# Score: 1.0
#
#
# Text: العما ولا ما بتفرقوا عن البقرة بتعد  عن الأنوثة ملايين  ما بعرف كيف عاملين مطربة
# Score: 0.8460262417793274
#
#
# Text: احلام انقلعي عنا يا بدك كنتاكي انا برءيي نتاكي احلا
# Score: 0.9523257613182068
#
#
# Text: هادي ماتشرفنا نحن الخليجيين 😠 لانها دقاقه ( طقاقه ) اصلا فتفكيرها وتصرفاتها على هالاساس
# Score: 0.8120304346084595
#
#
# Text: ياسبحان الله شو مكروها هالفنانه عليها صفات الخنازير وشكلها اشكال بقر الفريزن انتي مش احلام انتي خرابيط لو انا زوجك انتحرت من زمان
# Score: 0.9058259129524231
#
#
# Text: mbc انتو قناة معروفة ومحترمة شنو هاي الخايسة احلام مخلينهة بالقناة والله خربت قناتكم
# Score: 0.8296688199043274
#
#
# Text: هذ الفنان احلام  مو فنانه
# سامجه وتافهه والاهبل الي يسمع اغانيها
# والواضح ان البرنامج جايبها يضحك عليها ويالجمهور
# Score: 0.9052445292472839
#
#
# Text: افادنا مراسلنا من مكان اراب ايدول هناك انباء عن جريمة وقعت في اراب ايدول وهيه اغتصاب المذيعة ... والمشتبه به احلام
# Score: 0.0047644986771047115
#
#
# Text: هههههههه احسن ماشاركت لان هي بقره من صدك من طلبت الكنتاكي في البرنامج وبعد كل هذا. خريجه شريعه اسلاميه
# Score: 0.8374301791191101
#
#
# Text: أحقر إنسانة شفتها في حياتي بصراحه لا دين ولا أدب ولا أخلاق ولا شكل أستغفر الله العظيم بس
# Score: 0.5722199082374573
#
#
# Text: يقطعها بهزول تقول قدامي غودزيلا أو شمبانزي لسه هظول أحلى منها بكثير
# Score: 0.9079238772392273
#
#
# Text: شاذة جنسيا .. ربما تكون خنثيا فملامح وجهها وخشونة جسمها قبل التجميل توحي انها ذكر والله اعلم .
# Score: 0.0
#
#
# Text: ذكر تحول الي ذكرين وحدة بشعة بكل شي شكل اخلاق كل شي صوتك زبالة ملكة ع نفسك يامامي
# Score: 0.7473903298377991
#
#
# Text: كل  المطربات  يحجن  بس  الثوره  أحلام  تسكت  ياحمار
# Score: 0.5710568428039551
#
#
# Text: طيب ما تفتحيها بورنو ياباراديس  امريكا مفتوحة علي البحري وفي مخرجين هناك
# في أمريكا هيريحوكي
# Score: 0.8397966623306274
#
#
# Text: قابضين ع برديس و سايبين هيفا العاهره و مايا دياب و غيرها ناس شراميط
# Score: 0.9227532744407654
#
#
# Text: البقره احلام هيا كانت بقره بس أريد أفهم اشسواها ملكه احلام البقره ههههه
# Score: 0.708000123500824
#
#
# Text: النظام خبيث يصنع يوسخ يلطخ اهل السنة الاسلام ينما غافل عما يفعل الظالمون
# Score: 0.1372855305671692
#
#
# Text: أسمك يهودي ولد القحبة اليهودي يشرفك مسلم إرهابي داعشي
# Score: 0.3925359845161438
#
#
# Text: تربحهم دخلوها البلاد حيط مزال بالله ميصليش يسكر ظد الشي معجبهمش القران يجيبو احكام
# Score: 1.0
#
#
# Text: يجب يكونوا نعالا لايران روافض يقتلون السنة افريقيا أليس
# Score: 0.27370554208755493
#
#
# Text: زمان الفتن اللهم أقضي اعداء الدين ربي دنيا دوم لحد لفلوس تقعدش عمركم تتقدمو بلاد عملاء لصهاينة
# Score: 0.7286537289619446
#
#
# Text: صحيح ليسوا بشر يجب وضعهم السرك المزابل التخلص أنهم الكلاب المسعورة
# Score: 0.09163415431976318
#
#
# Text: تجوع الثعلب التونسيه تتحول أنثى العنكبوت تقتل زوجها بمجرد الانتهاء عملية التزاوج ليلة الدخلة ههههههه
# Score: 0.17160053551197052
#
#
# Text: ههههههههه يتونسي يكذاب يبلاد الفقر وشحاتين حني لليبين بلادنا حرب واحسن بمليون مره موجود ماعندكم ربعه
# Score: 0.9284073710441589
#
#
# Text: يهبط الوباء المرض سبسي بشرى حكام تونس فردا فردا يزلزلها اقدامكم
# Score: 0.2761193811893463
#
#
# Text: اخوتي التونسيين كنتم تريدو يحل عنكم البلاء فعليكم بمن يحارب الشريعة الاسلامية بلادكم
# Score: 0.06980264186859131
#
#
# Text: الهم انصر المجاهدين الخروج الحاكم شرعي يجوز الحكام العرب ليسو شرعيين وبارك هدا شاب مشاء علبه
# Score: 0.012503035366535187
#
#
# Text: تونس لديها إعلام يد الشيوعيين والحداثيين لذالك تستطيع تعرف قلي بربك الكفار ينشرون الحق
# Score: 0.17626921832561493
#
#
# Text: اولا تونس بلد مثقف بلد المليون قحبة والسقاطة والعاهرة والقذارة والنجاسه عاهرة
# Score: 0.0415629968047142
#
#
# Text: مؤامرة عالمية الدين برعاية أمريكا اسراءيل الشعب مسلم يستسلم ربي ينصرنا الحرب
# Score: 0.13336390256881714
#
#
# Text: حسبي الوكيل طفلة طفل تونسية المساوات يجي نهار ربي يعرف شيعمل كلاب زايد أبهم شعب هوما التوانسة والله
# Score: 0.8438971042633057
#
#
# Text: موسيو حبس هههههههههههههه العلمانية اليهوذية قتلت الروح التونسية الطريق الجزائر
# Score: 0.40685275197029114
#
#
# Text: هههههههههه الفيديو استنتجت الشعب التونسي أغبى شعب العالم النساء الرجال ڨاااااااع حمير بعزيز تفوو كفار زبيييي
# Score: 0.6530488133430481
#
#
# Text: نقبلوا الجزائري والمغربي تونس السود الأفارقة فغير مرحب جراثيم فتاكة
# Score: 0.39580923318862915
#
#
# Text: خويا الساحلية ولاد قحبة يفطرو رمضان مهمش الرجال جماعك الجنوب خاطينا برجالنا
# Score: 0.972178041934967
#
#
# Text: رسولك ارهابي يزبي توجد تاريخيا محمد الرسول الوحيد فبركة ماهوش موجود اذاكة عندو قبر صورة
# Score: 0.46295857429504395
#
#
# Text: الحق الرىيس التونسي الحق الشباب التونسي يحملو السلاح اعلان الجهاد قتل الكفار
# Score: 0.025261199101805687
#
#
# Text: بعران الخليج غنم امريكا سبب بلية العرب خلو تونسي جزايري مغربي مصري
# Score: 0.20076967775821686
#
#
# Text: لعنه الشعب التونسي الساكت والخانس لعنكم
# Score: 0.23563320934772491
#
#
# Text: بلدك تونسي علماني ملحدي يحتاج فتح إسلامي جديد الاباضية جزيرة جربة وغيرهم الصالحين تفوووو كافر
# Score: 0.29934656620025635
#
#
# Text: الحق وهجمو الداعرات العاهرات التونسيات لوثو الخليج مقززات يشتغلون بالدعاره ارحلو لانريد تونسيات بالخليج الكرامه
# Score: 0.3818845748901367
#
#
# Text: بعل آمون رد بالك توصل الليبيات ياتونسي يابغل
# Score: 0.9725207090377808
#
#
# Text: لطيف لطيف ربي لطف وصالنالو يحرقكم نار جهنم
# Score: 0.5887647271156311
#
#
# Text: خويا هذو المخنثين يتهز العرش العالي وملعونين واكثر قوم هذبهم بداية الخلق القيامة قوم لوط السلام االله ينظف الارض
# Score: 0.6170960664749146
#
#
# Text: شعب جاهل ومتخلف يحب الخير لأمه وأخته دين ذكوري وإحتقار المرأة تسعى وتشتغل مثلها الرجل
# Score: 0.041184429079294205
#
#
# Text: فيصل خالد احسن بردت قلبي ليبيه وأكره تونس بلد الدعاره وبلد الإرهاب تحيا الامارات تحيا الامارات العربية
# Score: 0.7820644974708557
#
#
# Text: يحق لاي ولد قحبه خارج تونس يسمعنا رايو
# Score: 0.7271093130111694
#
#
# Text: الفيديو أكبر دليل وبرهان كفر الدساتير الوضعية دستورنا القران يلتزم يطبق الحد غصبا الحكومة الملحده
# Score: 0.1669977903366089
#
#
# Text: يستاهلو شعب طحان جيعان اللهفة ميغلو ميزيدو يشرو سيب تاكدت تونس شعب
# Score: 0.9182550311088562
#
#
# Text: ربي سافيك غالط سفيك دين الإسلام غالط بلاد تونس بلاد ديوثين
# Score: 0.6260312795639038
#
#
# Text: شعب جاهل وحكام فاسقين كلاب إمريكى والصهاينة
# Score: 0.024123718962073326
#
#
# Text: الحمد لله مجيتش تونسي اقسم بالله حيروني
# Score: 0.9390649199485779
#
#
# Text: نقبل بالمغربي والجزائري والليبي تونس السود الأفارقة فغير مرحب جراثيم فتاكة ويجب القضاء دول المغرب العربي
# Score: 0.31799983978271484
#
#
# Text: شعب جاهل الدين حسبنا ونعم الوكيل الرئيس التونسى هنشوف
# Score: 0.06680183857679367
#
#
# Text: بلي نقلعو الصوم اعلمو جهلاء ملحدين المسيحيين اليهود يصومو الأوربيين يصومون الصوم مليح للصحة
# Score: 0.5405568480491638
#
#
# Text: المخنثين الجزائر ولاية تلمسان المخنثين يفتحوا ترمهم هههههههه
# Score: 0.535798966884613
#
#
# Text: التوانسة المتخلفين جرأة يعملوا استطلاعات رأي موضوع مجرد النقاش والتشكيك كفر أكبر مخرج الملة
# Score: 0.26150280237197876
#
#
# Text: سيدي القحبه امك مصري كس امك جزائرية غبي القحب كسمك لغتكم سب سب
# Score: 0.9133358597755432
#
#
# Text: انبح كلب الملاحدة يمشي معكم السيف
# Score: 0.5158435702323914
#
#
# Text: خلك الاحترام والضعافه اليهود كمسلم اكون جبان ليهودي
# Score: 0.7375803589820862
#
#
# Text: هههههه صح لسانك تونس شراميط صغير كبير لعن إخوان الشياطين
# Score: 0.7711573243141174
#
#
# Text: المواطنون المواطنات متساوون الحقوق الواجبات انتهى الدين الاسلامى يعرفوه الفلوس النيك شعب منافق
# Score: 0.36376678943634033
#
#
# Text: رجال تونس اعطيوتو المراة حقها اصبحت تتطاول اخ الجزائر
# Score: 0.49134403467178345
#
#
# Text: زب تونسي خرم طيزك طيز ليبيا العراق قحبة
# Score: 0.711907684803009
#
#
# Text: اللهم سلط عذابك شعب يستاهل الحرق
# Score: 0.310705304145813
#
#
# Text: هيدي عتريس مش برديس....فتشو منيح رح يطلع عندها قضيب
# Score: 1.0
#
#
# Text: الاعتذار العلنيتي قلتلكم يولدي رهي تونس تبيع انسها رجالها هههههه وبالمناسبة هدي نقترح تغير اسم الدوله تونسيه دولت بول وتعده ههههه
# Score: 0.636495053768158
#
#
# Text: يسدد شباب الامة يبدد تضليل الطواغيت
# Score: 0.01213916391134262
#
#
# Text: انسانه حيوانة كلبه فلوس اخرتها جهنم ان شاء الله 😠👎👎👎
# Score: 0.6972885727882385
#
#
# Text: الفيديو عنها قمة الاحترام معروف لانها عاهرة
# لو شافت فيلم جنسي تقولنا هو قمة الاحترام و الادب
# Score: 0.8426035046577454
#
#
# Text: الجسم صدره حليب ديود كس مص وردي نقب مفتوح
# Score: 0.6193796992301941
#
#
# Text: هيفاء وبرديس ومروه وفيفي عبده وسما المصري وغيرها شويه عاهرات وانشالله كلهم فنار جهنم للابد حسبي الله ونعم الوكيل فيهم
# Score: 0.714232861995697
#
#
# Text: انتي عايزة سرير ويكون معاكى ٤ رجالة يفرتكو كس امك نيك..انتي تمامك كدة
# Score: 1.0
#
#
# Text: اللي يتكلم ويرفع صوته علي البنت ابونظارات جزمتها فوق راسك ياابن الحرام
# Score: 0.9243687987327576
#
#
# Text: هههههه ترحولها فدوة ...هيفاء وهبي وميريام فارس ودومنيك ههههه مو ساقطات والخليج لاعبين بيهم لعب وحتى باقي الفنانات كلهم ساقطات بكيفها....والله يالله
# Score: 0.9918714165687561
#
#
# Text: شرمووووووووووطه جداً الوسخه ديه نفسى أشوفها هتموت ازاااااااى 🙄🙄🙄🙄🙄🙄🙄🙄🙄🙄🙄🙄🙄🙄🙄🙄🙄🙄🙄🙄🙄
# Score: 1.0
#
#
# Text: شاء إخوتنا امازيغ جربة الإباضية سيقطعون رأسك كافر
# Score: 0.19839052855968475
#
#
# Text: هههههههههههههههههههههههه وبيجيك تووانسة يقلك يجب نقل الحج وتدويله روحو نظفو بلدكم كلاب تونس
# Score: 0.9985703825950623
#
#
# Text: الشعب التونسي شعب ديوث ويعطي رأيه احكام القرآن الكريم ويقول الموضوع لايهمه لاحول بالله العلي العظيم
# Score: 0.026450978592038155
#
#
# Text: لطفي يشوف روحو فحولة زايدة الاخ باشا جابد شوي لتخنث ونا نقول السيد باشا محترم مسترجل افضل سي لطفي
# Score: 0.9087995886802673
#
#
# Text: يعاهر يولد دوله الدعاره والفسق تحني مسميين دولتكم دوله تغيير الزيوت يجاهل
# Score: 0.4642207622528076
#
#
# Text: قدمت للفن تونسي والعالمي القحب العهر والانحطاط الخلقي ارخس عبدة الكون خامجة حقيرة
# Score: 0.09875365346670151
#
#
# Text: ربي يتوالكم توانس شعب مسلم علمانين
# Score: 0.42963629961013794
#
#
# Text: والله شعب جاهل خليتو الدين تبعوا الدستور
# Score: 0.9056900143623352
#
#
# Text: عطاها زلعة حلوة وتستاهلها عدوة الدين المدعية الثقافة والتقدم وقتلك تونس مدنية
# Score: 0.5816051363945007
#
#
# Text: لاتحزن نساء قحاب معرفه تونس تيلند هههههه وبره سرك بير
# Score: 0.35531917214393616
#
#
# Text: حمير وجهال تصيم الحمير لاتصيم وتونس لاتصيم كس امك نايكه ليبياوالجزائر اكتر شعوب ناكو بناتكم ههههه
# Score: 0.6121108531951904
#
#
# Text: نقبل المغربي تونس سود الأفارقة فغير مرحب تونس جراثيم فتاكة
# Score: 0.49288317561149597
#
#
# Text: شعب يجهل دينه للأسف رحم ربي
# Score: 0.004117406439036131
#
#
# Text: شو هيدي الفنانه ،،قي قمة السفله
# راغب وشمس وفرح ونانسي تاج ع راسها
# لتخلوها في برنامج ارب ايدل موسم 4
# كل يكرها ميحبها
# Score: 0.9914502501487732
#
#
# Text: أحلام فنانة كبيرة ومن يتكلم عنها هم غبار على أقدامها
# Score: 0.010924777016043663
#
#
# Text: مكروهة محد طايقها لازم تفهم انا مو من مصر بس بكرهاا واعتبرها اهانه لمصر
# Score: 0.7728423476219177
#
#
# Text: اسكت اسكت مش طلعت سما عطيه حدائه بنت حداقه بتاع الفول ومرتضى عارف قصتها لووول
# Score: 1.0
#
#
# Text: يا جماعه اصلا برديس ديه كانت شمال بفلوس قبل موضوع الرقص وكانت بتطلع اوردرات في المقطم
# Score: 0.9594847559928894
#
#
# Text: شعب منافق يصفونه باسوء الاوصاف وخلال ساعات من عرضه تصل مشاهداته للملايين
# Score: 0.10380657017230988
#
#
# Text: كل بنت بدها تطلع من الفقر صارت تشلح 😣
# Score: 0.9228299260139465
#
#
# Text: ليش هيج خلي إخوانه المصريات منساتنه ههههههه يعني الواحد يجيب مزة وربعيه عرك ويطلع أي قناة مصريه وضرب يعم هههههه
# Score: 1.0
#
#
# Text: الحق ليس عليها الحق على الناس اللي دايرنلها الشأن ومسمنيها فنانة !!
# Score: 0.52553790807724
#
#
# Text: والله انا اعرف المصرين شعب شهم وقدع والله هاذو دخلا ء عليكم
# Score: 0.37036997079849243
#
#
# Text: فعلا الشعب المصري شعب عظيم وكم كائن حقير متل هاي الكائنة شوهت صورتهم .... الله يسطفل فيها وبأمثالها ... وخساره فيها شعرها -_-
# Score: 0.6829859018325806
#
#
# Text: واو على هالليلة كلها مفاجئات م وى وبرديس وميريام كلينك شي مقرف
# Score: 0.7495238780975342
#
#
# Text: تفو عليها وعلي زيها يخسارة شوهت مصر
# لا حول ولا قوة إلا بالله 😡😡
# Score: 0.8138697743415833
#
#
# Text: سااااااااااااقطة بامتياز  وان شاء الله تموت عالمعصية والرذيلة  ﻻنو عقاب ربنا سبحانو  هو الكفيل بانو يشفيلي غليلي فيها
# Score: 0.37640058994293213
#
#
# Text: اويلي قمة الادب والاحترام وعلاه قمة الانحلال والفسق كيفاش داير
# Score: 0.8670526146888733
#
#
# Text: والله برديس شكلها زي القرد اصلا وصوتها زي الرجاله وكلها علي بعضها تقرف
# Score: 1.0
#
#
# Text: فعلا الأشكال دي خلت كل العالم يظن ان المصريات كلهم عاهرات  زي الناس دول
# الله لا يوفقهم ويخلصنا منهم
# Score: 0.7391646504402161
#
#
# Text: المفروض القزاره دي مافيش حدا يعرضه التلفزون المصري ابدا
# Score: 0.9674562811851501
#
#
# Text: كل ما اشوفها احسها ذكر متحول استغفر الله العظيم
# Score: 0.4629089832305908
#
#
# Text: العيب مش عليها العيب على الأشكال الوسخة الى بتجيب الأشكال دى وتسئ للشعب كله
# Score: 0.9792989492416382
#
#
# Text: اكبر شعب منافق هم مصريين في اعراسهم يجيبو رقاصات وفي الحصص عاملينو انهم شيوخ هههه
# Score: 0.8240621089935303
#
#
# Text: الله يلعن الفن ويمسحو من الوجود هو سبب خراب النساء
# Score: 0.5421362519264221
#
#
# Text: يقول أحد الفلاسفة : إذا أردت أن تعرف رقي أمة فانظر إلى نسائها
# هذه و أشكالها عالة و عار على مصر و الامة العربية
# Score: 0.0
#
#
# Text: بغض النظر انها مقززة و مبتذلة و مقرفة لكن من انتم لتنصبو انفسكم حكاما عن الناس??? لها رب اسمه الله يحاسبها و يحاسبنا ارتقووووو
# Score: 0.1321430802345276
#
#
# Text: انا اصلا حدفت كل القنوات الفضائية المصرية  لأنهم سرطان للأطفال الصغار
# Score: 0.514378547668457
#
#
# Text: فرحت يوم انها انسجنت .. جعلها سجن مؤبد يارب
# Score: 0.3834777772426605
#
#
# Text: هذا النوع من الفتيات في الجزائر نقولولهم سوسيالات social 😉
# Score: 0.3891346752643585
#
#
# Text: هم  الوسط الفن كلو عاهر بلا سعاد حسني بلا خيبة
# Score: 0.5263989567756653
#
#
# Text: اعطوها شي اعلى من قدرها رقاصه وكل ليله في حظن واحد شي مقزز والله
# Score: 0.5302368402481079
#
#
# Text: يعني هذا اللي قاعد يتكلم اتكلم عن هيفاء وهبي اوك شي عادي لكن اليسا اكيد لا لانهو اليسا من ارقى الاصوات العربيه حاليا شهالتخلف
# Score: 0.8346869349479675
#
#
# Text: ربنا يهديها .. دي حتتشوي شوي انما ايه نااار جامد يوم ما تموت 👻
# Score: 0.8820971846580505
#
#
# Text: قمة الانحطاط يا حسرة على هيبة العرب الي راحت بسبب هذه النماذج المخربة للمجتمع العربي المحافظ
# Score: 0.281183123588562
#
#
# Text: ههههههههههههههه المصري عجبني لما تكلم عن هيفاء واليساا ياككبيييييييييييييررر ههههههههههههههههههههههههههههههههههههههههههههههههههه معاه حق والله 👍🏼😂
# Score: 0.8086193203926086
#
#
# Text: هذي مصممه انها محترمه هذا مجنونه رسمي ربي يقلعها شوهت البنات محترمات لما تضم حالها منهم المفروض هذي يوقفوها ايش الاحنطاط هذا
# Score: 1.0
#
#
# Text: العيب مش فيكي العيب في البيستضيفك والرغابة الي وافقت تعرض اشكال زي دي
# Score: 0.9168427586555481
#
#
# Text: راغب دوله وعلم كلهم ايغارون منه اولهم احلام 😂سواهه وبجاهه لل الخبيثه هاي امسميه روحه الملكه انتي ونعالي ملكت الغيره ترهم اكثر 😂😃😥😎
# Score: 0.618778645992279
#
#
# Text: في موضوع راغب علامة معها حق... راغب علامة مال سخرية على الاخرين وبس وصوته فاشل
# Score: 0.6119286417961121
#
#
# Text: اللهم عافينا سفله وبرنامج سافل وليتهم يجمدون ارصدتها الي من جيوب الاغبياء الي بسمعونها....نسأل الله حسن الخاتمة
# Score: 0.6711955666542053
#
#
# Text: انتي مغروره وصراحه كلامك خرا شبهه وشك ههههههههههههههههههههههههه ال ملكه ال تعالى اقعدي علي دا l
# Score: 0.9796212315559387
#
#
# Text: وجهها تقول سطل ادهان وجسمها كله سليكون باقي المواسير وتكمل السباكة😂😂😂😂
# Score: 0.9955445528030396
#
#
# Text: عفية مصر شكد فساد بيها  بكل مكان فساد حتى مظاهراتهم لازم بيها تحرش جنسي شعب نابع على فساد
# Score: 0.9158101677894592
#
#
# Text: بصراح مصر بلد حلوة بس الاشكال دي عار عليه
# Score: 0.9484648108482361
#
#
# Text: يا جماعه الراقصات دول ملهومشي اصل بنات شوارع. والاعلام بيصور للعرب ان مصر عباره عن العاهرات دول نسبه السنه 60في الميه من سكان مصر.
# Score: 0.8101809620857239
#
#
# Text: ههههههههه يعني سعاد بالجنه معطينها اكبرررر من حجمها مين سعاد حسني فاجره وكاسيه وقله ادب يعني احسن منهم بايش نفس بعض الحمد لله وشكر
# Score: 0.8465474843978882
#
#
# Text: مصر ولاده يا جدعان وياما حتولد القزاره دي 😷
# Score: 0.985297679901123
#
#
# Text: المذيعين اوسخ من برديس لأن يشهرون برامجهم بلقائها هي وأمثالها وعاملين نفسهم شرفاء الي متل برئيس لازم ماتطلع حتى عالبرامج
# Score: 0.6181315779685974
#
#
# Text: شو هل وساخة يا جماعة عيب والله عيب هاي لازم تعمل زي مياة خلية 😂
# Score: 0.8491830229759216
#
#
# Text: اول مرة نسمع بهاد خيتي 😒😏 لي لقات فورمتها زينة تعريها وتقول انا مغنية و فنانة لعفن ولا ماشي الفن 👎👎👎
# Score: 1.0
#
#
# Text: الشعب المصري شعب نظيف والله واعرف كثير نظيفين بس من جد الأشكال هذي تشوه مصر
# Score: 0.6892324090003967
#
#
# Text: هيفاء وهبي غنات لسعاد حسني أكبر عاهرة في الوسط الفني
# Score: 0.4000038206577301
#
#
# Text: طيب وهيفاء وهبي ليه مايسووا فيها كذا ؟؟ مايا دياب و فنانات كثير خادشين للحياء ... من زين الفن المصري اصلا اغلبه جنس وقلة حيا
# Score: 0.945701003074646
#
#
# Text: والله الأشكال دي وسخت سمعة مصر صارت مصر بلد الراقصات والعري
# Score: 0.9613081216812134
#
#
# Text: سعاد حسني قدمت مشاهد جنسية وادوار جريئة اكثر من برديس والأرشيف موجود والوقاحة انهم بيقولو ما توصل لربع سعاد حسني ازدواجية وتناقض عند الشعب المصري
# Score: 0.3079491853713989
#
#
# Text: هههههههه العيب ليس في العاهرات العيب في من يعطيهم قيمة ويجعلهم فنانات  وهم عاهرات من الطراز الأول
# Score: 0.2357553392648697
#
#
# Text: وانا عمبالي فوهران عندنا القحاب😛😂 ظهرت ماشي غير عندنا
# Score: 0.8133688569068909
#
#
# Text: شكلها يضحك وهي تتكلم انجلش تقول اكسيوز مي مش اسكيوز مي
# Score: 0.850290834903717
#
#
# Text: والله لي يحجي على أحلام يغار  منهه لأن أحسن منه
# Score: 0.9743407964706421
#
#
# Text: احلام  خلك من ذول كلهم و روحي عند طفاح يمطك
# Score: 1.0
#
#
# Text: الهبلة هي اكيد مريضة نفسيا اتفه و ابيخ واسخف مخلوقة بشوفها بحياتي "صوتا وشكلا وتصرفاتا"
# Score: 0.924584686756134
#
#
# Text: أحلام احلى شي تروحلج فدوى شذى  حسون  أم الوصخ إني من العراق😗😗😗
# Score: 0.8824349641799927
#
#
# Text: أفضل شي لك يخبل مستشفي المجانين وبس الخروف
# Score: 0.939991295337677
#
#
# Text: ناس متخلفة جاهلة فاشلة مالها غير الحكي ع الناس .. احلام فنانه كبيره .. صرمتهاا بكل المغنيات واولهم نانسي
# Score: 0.9579372406005859
#
#
# Text: الله يقلع الاشكال ذي والي اعطاكي وجه
# Score: 0.9368478655815125
#
#
# Text: صدقت شعب معتر ويلي عم يدفع ثمن شعب ااااااااخ
# Score: 0.7397273182868958
#
#
# Text: العرب لم يتخذوا الانترنت الا لسب وشتم بعضهم بعضا ....يا أمة ضحكت من جهلها الامم
# Score: 0.11784481257200241
#
#
# Text: عند شوهت صورة الخليجيات لاسلوب ولا اخلاق عل  ملكه ترى الادميه صدقت نفسها مررره
# Score: 0.6480016112327576
#
#
# Text: هبلا ووحقه حتئ مابتعرف تتكلم وتنسق كلامها ووووع
# Score: 0.9691185355186462
#
#
# Text: ياويلي من الغيره من احلام ذبحكم الحسد و الغيره منها يويو منكم الله يكفيها شر عيونكم
# Score: 0.46785932779312134
#
#
# Text: هل الفنانات ذبحتهم الغير والحسد من احلام ..
# Score: 0.028423653915524483
#
#
# Text: شو يقولونها بالعربي 🌚 الحرمة من الجذور البريطانية 🤔
# Score: 0.6180709600448608
#
#
# Text: الي يشوف أحلام زمان شوف أحلام مع جورج قرداحي في برنامج من سيربح المليون كانت قمة الأخلاق والذوق وش إلى سار ربما حاله نفسيه
# Score: 0.7935086488723755
#
#
# Text: هههههههههههههههههههههههههههههههههههههههههههههه ناس فاطية وتافهة ربنا ينتقم منكم
# Score: 0.8523513674736023
#
#
# Text: صاحب المقطع متخلف وحقوووووووود
# دعواتي لك با الشفاء وانا متأكد انك من الصحافة والحاقدين
# Score: 0.2226615846157074
#
#
# Text: بالله عليكم فيه فنان عربي مثقف ورزين وعاقل ؟ يمكن قلة قليلة وكمثال كاظم الساهر أصالة نصري، لكن الاغلبية بهذه الصورة
# Score: 0.35008952021598816
#
#
# Text: شوارعية بيئه حتى اغرائها مقرف جسمها بشع مقزز مافيها نعومه كانها رجل متحول ومصرة على قرفنا واستفراغنا روحي ربي عيالك
# Score: 0.6837250590324402
#
#
# Text: اقول كيف الحال بس..اصلا ما جابوها في البرنامج الا عشان المقاطع اللي مجمعها انت ووجهك...لايكثر وروح كمل سيخ الشاورما لا يزعل عليك المعلم بس.
# Score: 0.9582651257514954
#
#
# Text: ا اوسخ واحده في العالم كله حسبي الله ونعم الوكيل فيها وفي اللي زيك
# Score: 0.7822793126106262
#
#
# Text: دي وامثالها هما اللي مسوئيين سمعة مصر حسبي الله ونعم الوكيل
# Score: 0.7444477677345276
#
#
# Text: هذة الست مقتنعة بملابس الكلب القذر بتاعها بالحترام.. سؤال ماذا ترتدي او تلبس في منزلها او غرفة نومها.....اكيد بتلبس عباية سوداء شكل وشها
# Score: 0.688776433467865
#
#
# Text: مصيرك جهنم أيتها الفاصقة والفاجرة لعنة الله عليك ستعلمين ذلك يوم لاينفع فيه مال ولا بنون إلا من اتي الله بقلب سليم.
# Score: 0.007206370588392019
#
#
# Text: بتقول انا عايشه علشان تدلع نفسى وادلع الناس ونسيت أن ربنا خلقها علشان العباده لله  حسبى الله ونعم الوكيل
# Score: 0.7268314957618713
#
#
# Text: حقا  هذه  تعتر  فنانة   هزلت
# Score: 0.24067798256874084
#
#
# Text: طاح حضج وحض فنج وياج انتي وامثالج خربتو الاغاني اغانيكم كلها وصخه مثل وجوهكم يا فشله
# Score: 0.9959907531738281
#
#
# Text: الله يخرب بيتكم سوأتم سمعت المرأه المصريةالأصيلةكل الدول العربيةواخدةفكرةانناكلناراقصات وغواني حسبي الله ونعم الوكيل فيكم بقينافي زمن البلاوي نفسي اعرفلك راجل فعيلتك فوش اموشنب
# Score: 0.8630632758140564
#
#
# Text: يخرب بيتك ما ازنخك لا صوت ولا شكل لا وبتدافع عن قرفها خيبه تخيب منظرك تفوووو ع شكلك  ي غبيه
# Score: 1.0
#
#
# Text: طوني خليفه يتكلم عن الاحترام و ناسي بنات ديرته ، اكبر شراميط بلبنان عندكم خلك ببلدك اشرفلك
# Score: 0.8277699947357178
#
#
# Text: ههههههه خلعوني تحيا الجزائر حمد الله معندناش هادوا الاشكال
# Score: 0.9422516822814941
#
#
# Text: شكراً لحضرتك ع هذه المهنية و النقد الجريئ لجميع عاهات مجتمعاتنا المتفككة المغلوب ع امرها..احييييييك و نتمنى الاستمرار و النجاح لك بهذه المهمة الانسانية السامية..
# Score: 0.2073632776737213
#
#
# Text: احلام اروع فنانات العرب وهي الملكة من جد عن جدارة والي ميتين غيرة منها ومن جمالها وصوتها الملكي يموت بغيرتو
# Score: 0.5141053199768066
#
#
# Text: اتمنى انه ما ماتكون بلجنة الحكم للموسم 4 فشلتنا وفشلت الخليج كله عند العربان والناس صارت تظن ان بنات الخليج مثل احلام
# Score: 0.23585519194602966
#
#
# Text: هي بتقول انها مسلمة و بتصلي... و كل طلعاتها بعرب ايدل كانت سكرانة و خجلت بقية اللجنة
# Score: 0.965060293674469
#
#
# Text: هذه على ما أظن لم تتمتع و لم تلعب في صغرها و بالتالي اصيبت بما يسمى بالفرنسي retoure d age
# Score: 0.06622063368558884
#
#
# Text: و الله عيب نقيم اوباش مثل احلام المريضة عقليا و رفعها الى مكانة لا يستحقها الا اهل العلم و القيم
# Score: 0.29365038871765137
#
#
# Text: مع الاسف على قتاة ام بي سي   ان تعمل عمل مع هيك  بشر زي الحشر
# Score: 0.7354546785354614
#
#
# Text: انسانة انصحها تروح تتستر وتطلب ربها المغفرة  .. عار على كل خليجية ..  تفشل  وتخزي...
# Score: 0.5065057873725891
#
#
# Text: بالفعل هم اللي عندهم مشكلة وبس يتمصخرو  عليها .. رهيبة يا أحلااام قاهرتهم
# Score: 0.9146654605865479
#
#
# Text: احلام وحده جاشره و ترباية شوارع لا اخلاق و لا فهم و لا جمال الواحد يقول الحق بتشنهق حلو المره
# Score: 0.6116250157356262
#
#
# Text: شي مقزز فعلن لانها رجل مبينه هي وهيفاااا ماجيك 😤😤😤
# Score: 0.46539759635925293
#
#
# Text: يااا الله تعبت واني اباوع متحولين جنسيا يا الله دنقرضووووااا
# Score: 0.5580587387084961
#
#
# Text: ليش كل الشواذ أو المتحولين يتحدثوا باللهجة اللبنانية ؟؟؟؟
# Score: 0.743695080280304
#
#
# Text: ياعراقي يا مصخم العراقيين اهل الشقاق والنفاق خو هلمثل مو مني لا وطلع واحد عراقي هيك والله كملت
# Score: 0.8574203848838806
#
#
# Text: هسه اصلا مو بالعراق لأن لوبالعراق كان قتلناه ببلوكه لو يمسكو الجيش يحلق شعره
# Score: 0.8712441325187683
#
#
# Text: الروافض يسبون الخليج ويتهمونهم بالشذوذ ومايشوفون حالهم على فكرة العراق من اكثر الدول انتشر فيها الشذوذ والجنوس في آخر كم سنة
# Score: 0.32593902945518494
#
#
# Text: هذا صدك عراقي
# لا بربكم هذا صدك لو شنو
# راح اتخبل والله ممصدگة العراقي ابو الغيرة هيج سوة بروحة گبرر الله ليوفقكم سويتونة مضحكة للعالم 😔
# Score: 0.872608482837677
#
#
# Text: وجعت مفاصل أمي .. أن شاء الله بيك .... يا عاااااااااااار ... واللي يگولي حرية شخصية ... هذا گرن ....وما يحتاج اجاوز بعد
# Score: 0.8197163939476013
#
#
# Text: مع احترامي لقناتكم بس انطيتوا حجم للحمقى وسويتوهم بشر وهمه حيوانات. منو هذا اصلا؟؟لاشايفيه ولانعرفه. اعوذ بالله
# Score: 0.7632323503494263
#
#
# Text: تعالي الطمي يا امل العوضي هوا احلى 😱😱😱😱😱😱😱😱 ااثقة في النفس بتدبح بس هان بتلطم وبتف اتفووووو
# Score: 0.9499766230583191
#
#
# Text: معها حق اسواء طيران شفتو بحياتي هوي الطيران المغربي الخدمي كتير سيئة عنجد حتى بال VIP عطول في تأخير! 😂😂
# Score: 0.8780437111854553
#
#
# Text: مقاس حذائي 43 ووجهك مقاسه 49 حتى حذائي طلع احلى منك
# Score: 0.5113451480865479
#
#
# Text: اذا جاءتك مذمتي من ناقص فهي شهادة لي بأني كامل ...ناس تافهة كاظم كبير مو محتاجة شهادة احد تحية لك من معجبة بأغانيك من الجزائر
# Score: 0.3897307217121124
#
#
# Text: اي يردون محمد عبدة فنان العرب باي طريقة طلعو هذا الفديو بعد دول الخليج حاقدين
# Score: 0.6397920250892639
#
#
# Text: بلة لحدةايكول على هاذا المسخ  عراقي اصلة مو عراقي زين  ولد العراق  أهل غيرة وشرف وعلى الرأس
# Score: 0.9212234616279602
#
#
# Text: من وين طلعلنا هاد كمان ...
# ياحسرة علينا نحنا هههههه الكل بدو يصير بنات
# Score: 0.9214856028556824
#
#
# Text: العمى بعيونهن أشباه الرجال الي يحبوا يظهروا مع هيك مناظر
# Score: 0.8028154969215393
#
#
# Text: السؤال المطروح هذا كيف دخل الإمارات شي غريب والله يسمحون لهذا الأشكال تدخل الدول المسلمة
# Score: 0.48671936988830566
#
#
# Text: شو هذه الكرات اللى حاطها على صدرك و وجهك مازالو وجه الرجل ليس لديك اَي علامات الأنوثة
# Score: 0.7067975997924805
#
#
# Text: بس هو موعراقي شنو الي يثبت هو عراقي اصلا هذا ماله اصل عنده اكثر من لهجه يتكلم بيها
# Score: 0.9349514842033386
#
#
# Text: صخل حرام اصلا انته عايش اغبرررر اوووف شنو هالنماذج
# Score: 0.9420667290687561
#
#
# Text: مش معنى انك تكبر اعضائك بقيت انثى..بص لنفسك تانى كده ..شكلك راجل بردو رغم الكورتين بتوعك..
# Score: 0.8351271748542786
#
#
# Text: لو كنتي مغربية عن جد ماكلتي على بلديك تشدي اامغاربة انضف منك ok
# Score: 0.9672315120697021
#
#
# Text: بتتكلم وتقول الخليج واحنا بالخليج الايرانيه بقيت عربيه وتقول احنا كمان
# Score: 0.7203666567802429
#
#
# Text: لطيفة اكبر منافقة  تغني لمصر وتتودد للمصريين ايه النفاق ده يا لطيفة
# Score: 0.6794061064720154
#
#
# Text: لو لطيفه توصل لربع صوت فله لجزائريه انا بنتحر علنا لهلق بعدها لطيفه بتنشز انت فين و فله فين هههه
# Score: 0.9797928333282471
#
#
# Text: اي بصراحة لطيفه فنانه محترمةمقارنة مع باقي الفنانات وعندها موهبه غنائيه مو متل غيرا لي داخلين الفن للاستعراض والاغراء فقط
# Score: 0.5279076099395752
#
#
# Text: استغرب من الفنانات اللي يرضون يطلعون مع عادل كرم
# سفيهه وتلميحات قذرة احس عيب عع احد يرضى بهالتلميحات حتى لو من باب مزاح 🌚
# Score: 0.8416838049888611
#
#
# Text: نادين الراسي ...واضح جدا انها ميتة بالغيرة من سيرين ...من الاول منحبهاش و زدت كرهتها
# Score: 0.2524105906486511
#
#
# Text: العمى عم يزت جوزها.... شو هل الرجال مبين طنط
# Score: 1.0
#
#
# Text: يا ليتنا كنا معكم و نتونس ونسة 🔞 😉 عظيمه..
# اوف عذاب :(
# Score: 0.4784226417541504
#
#
# Text: صاحبة أكبر فايك اكاونت... وهي متصنعة.. كريهة جدا وغيورة من نادين نجيم مع انو نادين حاولت ما تعاديها
# Score: 0.6912997364997864
#
#
# Text: يا احلام ياعبده يابقره استحي على نفسك ياعجوز ذكرى الله يرحمها صوتها من اروع الاصوات بعدين انتي بقره
# Score: 0.6296285390853882
#
#
# Text: اخخخخخخخخخخخخخخخ تفوو عليك يا عيشا راجل انعيش فى الشارع و لا انشوف خلقتك
# Score: 1.0
#
#
# Text: أقل شي انج انطردتي يا رغدة من دولة الكويت
# Score: 0.39910900592803955
#
#
# Text: احلى شي في الفيديو المقطع الاخير يوم اكلت علقه محترمه😂
# مباقي يسب أم المؤمنين الي انتي يارغوه💦
# Score: 0.7706132531166077
#
#
# Text: اقسم بالله اللي حيلمسك لاكون دبحو
# دافع عن فنانه ولا دافع عن زوجه الرسول
# استغفر الله العظيم اللهم لا تواخذنا بما فعل السفاء منا
# Score: 0.5260129570960999
#
#
# Text: ههههههههههههههههههههههه تستااااااهل فقعوا راسها وضربوها خلوا عيونها تطير
# ههههههههههههههههههههههههههههههههههههههههههههههههههههههههههههههههههههههههههههههههههههههههههههههههه
# الله يبيّض وجيههم رجااااااااال ونعم الرجااااااال
# Score: 0.9935190081596375
#
#
# Text: الفنانين مسخروا نفسهم بالسياسة يا ريت كانت التهت بفنها كانت ظلت بقيمتها...هيك نزلت لسابع ارض
# Score: 0.5470761656761169
#
#
# Text: قعدت تهايط و جاها مصري وراها قيمتها كفووووو يا ابن النيل و الله كفووو
# Score: 0.8660510778427124
#
#
# Text: عاشا الجيش العربي السوري رغم انف السلفين الانجاس اللواطين
# Score: 0.039407189935445786
#
#
# Text: ههههههه هاذي من عطاها اكبر من حجمها الله يزيلها
# Score: 0.9009127020835876
#
#
# Text: الله ينصرك يا بطله والله رغده أشجع من ميت رجل
# Score: 0.3642401099205017
#
#
# Text: قال الكويت جزء من العراق ههههههههه حتموت من الحسد والحقد أما العلقه اللي اكلتها من المصريين 😂😂😂👍
# Score: 0.7501190304756165
#
#
# Text: ياريت كانت الطفايه قسمت دماغك نصين طظ فيكي اركبي تكاسي المال الحرام زي مبيجي بيروح بكره افكركم ان شاء الله هتموتي شحاته
# Score: 0.9646338224411011
#
#
# Text: هي هبلا الست دي ولا ايه والله حاسس انها اتجننت
# Score: 0.908710777759552
#
#
# Text: بعد بيتي يا الكدعان ، اوف اوف لو مكسرينها ، ما قصرتو اسباع
# العراقي
# Score: 0.9682725667953491
#
#
# Text: ماراح اقول غير ان ماقصروا المصريين فيها كفوو والله
# Score: 0.9459174275398254
#
#
# Text: الى مزبلة التاريخ إن شاء الله وموعدك يوم الجنائز
# Score: 0.0
#
#
# Text: مسكينة فقشو راسها تستاهل😂😂😂😂😂 ودي اشوف الي ضربها ولله لابوس راسهه
# Score: 1.0
#
#
# Text: والله لتخلف العرب انهم مستعدين لحرب ضروس، جماعة تنتصر ﻻحﻻم واخرى لراغب ،على راي المصرين يولعوا بكاز هما اﻻثنين.
# Score: 0.3478846549987793
#
#
# Text: كل هذا الكلام هو حسد للقيصر كاظم الساهر ولانه لابسكم لبست القندره
# Score: 0.282376229763031
#
#
# Text: يا مريض نفسي ويا غيور يتكلم عن القيصر تعرفون شنو القيصر إمبراطور الغناء العربي وقيصر الغناء العربي مقهورين من الملك
# Score: 0.499752014875412
#
#
# Text: مضغوطين من القيصر لان وصل مرحله عاليه  وهمة بقو
# Score: 0.442965567111969
#
#
# Text: الفنايين البنانين ماخذين مقلب بنفسهم محد يسمعهم لابلخليج ومصر
# Score: 0.9782447218894958
#
#
# Text: هههههههة ولكم اغنية وحدة من كاضم تسوة فنكم كلة
# Score: 0.9412029981613159
#
#
# Text: الجميع والفنانين الموجودين بالفيديو يروحن فدوة للتراب الي يمشي عليه كاظم الساهر ياسطورة الفن ياظاغطهم
# Score: 0.8083364367485046
#
#
# Text: كاظم الساهر تاج راسكم .. بس اخلاقه كافي .. وهذه الاعلاميه الكويتيه الي ماتريد تشوفه بلكويت هو كاعد بلوس انجلاس مارايدكم
# Score: 0.7054834365844727
#
#
# Text: الله يطيح حضكم ما لكيتوا غير القيصر تحجون عليه
# ومصيبه هذه العراقي اشون تحجي عليه ونصير اشماته
# Score: 0.9511199593544006
#
#
# Text: كل العالم صارو السبب بشهرة القيصر كاظم انتو وين القيصر وين يا مقهورييين
# Score: 0.8774053454399109
#
#
# Text: اي مو هو ميت على الكويت كاظم هي الكويت من حورها
# Score: 0.9626198410987854
#
#
# Text: ههههههههههههههه بلنسبة الى وائل جسار حبيبي مصر 75 مليون يعرفونك 5 مليون و70 مليون جماهير كاظم مايعرفوك ههههعع مغرور
# Score: 0.8059859871864319
#
#
# Text: متى كانت الخدم تتكلم عن الملوك ؟؟؟
# حبيبي هذا القيصر علم في رأسه نارُ
# والي ميعجبه الصحراء واسعه
# Score: 0.5441647171974182
#
#
# Text: كل شخص يتجرأ ويتكلم عن القصير يروحله فدووووووه لحذائه
# Score: 0.5146170258522034
#
#
# Text: والله العضيم معرفت من ذولة غير واحد لو اثنين بشرفكم بس وصلوا لصيت كاظم الساهر وتعالوا احجوا عليةةةة
# Score: 0.9567896723747253
#
#
# Text: حذاء القيصر على راس كل الي عم يحكي عليه وبدكن 19000000000000000000مليار الف سنة لا حتا توصلو لا لقبه وكبره ومحبت البشر له
# Score: 0.7647729516029358
#
#
# Text: احبك يا احلام تستاهلي انعل ابوك راغب اطلع برااااا
# Score: 0.8716750144958496
#
#
# Text: والله عيب...انتي لو ما فراش المنتجين و الملحنين ماكي فنانة...انتي مكانك في الملاهي يا سيدة الطرب ها ها ها ها
# Score: 0.8884143233299255
#
#
# Text: احﻻم من وين ل وين ملكه وبعدين بدك 100 سنه لتوصلي لربع السوبرستار راغب
# بس احلا شي لغتها اﻻنجليزيه عنجد خيله فديتك ياااااا ملكه ههههه
# Score: 0.9460052251815796
#
#
# Text: انا مع احلام لانها دقت خشم الكلب راغب الزق
# Score: 0.6266656517982483
#
#
# Text: الخليجيين يظنوا بانهم افضل من الاخرين بسبب فلوسهم بس لازم يعرفوا بان النخوه و العرووووبه فوق المال و الفلوس بالحذاااااء
# Score: 0.6753987669944763
#
#
# Text: و الله راغب علامة سيدك و أستاذك،لو مشيتي سترتي نفسك أحسن...
# و ما تصدقي إنك ملكة إلي سماك ملكة كذب عليكي، إنت vulgaire برشا برشا
# Score: 0.8171282410621643
#
#
# Text: كلهم أغبياء... القيصر..أسطورة وكاظم ما في متله صوت وصورة
# Score: 0.2455628514289856
#
#
# Text: الكويت عايشة بفضل العراق لان جزء من العراق وميناء مال العراق كافي
# Score: 0.4576115906238556
#
#
# Text: انبعاص جميع المطربين بين قوي (سعودي كويتي ) جلاب انبعصتو
# Score: 0.5509174466133118
#
#
# Text: يقول نبيل شعيل انا دخلت للكويت وما خفت من الغزو العراقي طبعا دخلت عامل نفسك فيل وعبرت علينا ههههههههههههههه
# Score: 0.5646553039550781
#
#
# Text: ليش ما تاكلون وحل احسن.. كاظم الساهر مو بحال هل وجوه الغمة... يبقى ملك ابو وسام
# Score: 0.8298604488372803
#
#
# Text: كاضم تاريخه وصوته وفنه يشهد اله مو جورج ولا هذولي الحته ما معروف اسمهم
# Score: 0.8574983477592468
#
#
# Text: اما جورج وسوف سلطان الطرب الاحظ انو كل العرب بيدافعو عنو حتا الفنانين ابو وديع ملك ملوك الطرب سيد الغناء
# Score: 0.6820182204246521
#
#
# Text: الاحظ دائما اللي بدفعو عن كاظم هم عراقيين وبدافعو عن كاظم بلشتم والكلام الوسخ وهاد بدل ع مستوى كاظم وجمهورو
# Score: 0.8664104342460632
#
#
# Text: اكل تبن محمد عبده ونبيل شعيل البرميل المن فلتت من البدايه ما بقيت اشو كالفهد بالركض من طفرت
# Score: 0.717866837978363
#
#
# Text: اجمل ما في الموضوع ان الفنان كاظم الساهر لم يرد على كل هذه الأصوات النشاز .. وجميعهم ينظرون اليه نظرة غيره وحسد.
# Score: 0.07667353749275208
#
#
# Text: ليش هالحسد زميلكم والله وفقة ونجح وكسب قلوب الجماهير العربية موتوا بقيظكم
# Score: 0.7459627985954285
#
#
# Text: ههههههههههه والله انت اغبى خلوق تقارن نفسك بكاظموكلهم غيرانين من كاظم والله اصواتهم موحلوة بس كاظم
# Score: 0.8070178627967834
#
#
# Text: الشجرة المثمرة ترمى بالحجر&ان لم يكن لك أعداء أعلم انك فاشل =أن لم أسمع كاظم سوف اسمع كاظم
# Score: 0.019861603155732155
#
#
# Text: كاظم الساهر تاج راسكم ترحون فده لتراب الي يمشي عليه
# Score: 0.6680414080619812
#
#
# Text: هو عراقي الكويت يردونه لبنان يردونه شطلعت هاي . انتو مقهورين 😂 معدكم مثله .
# Score: 0.9684720635414124
#
#
# Text: موتو من القهر  محمد عبده انته فاشل  نبيل شعيل  اسكت انته ابو كرش طلعت مسوي بطولت. والبقيه حيونات
# Score: 0.963542640209198
#
#
# Text: كاضم يسواكم كلكم واحنه العراقين نفتخر ان كاضم عراقي،#مضغوطين
# Score: 0.7476404309272766
#
#
# Text: نبيل شعيل صار رامبو ودخل بعد الحرب.. البرميل يسموه بلبل الله وكيلكم غراب الخليج
# Score: 0.5165403485298157
#
#
# Text: عود ليش عشاق القيصر متكبرين لانو هم يعشقوه والله كل واحد ويعشق فنانه حتى لو كان فاشل فالتكبر والانانية لعشاق القيصر مو لاحد 😒
# Score: 0.8320418000221252
#
#
# Text: هوة اسمة كافي القيصر عمي هم مضغوطين ضغطة قوية من كاضم الساهر
# Score: 0.784578263759613
#
#
# Text: يا اخي ما شفت ناس تحقد مثل الكويت وبالنسبة لكاظم هو ستار غصبن على الكل
# Score: 0.7046894431114197
#
#
# Text: الكل غير من كاظم لأن هو نجاح وانتو فشلين
# Score: 0.675464391708374
#
#
# Text: لانه عراقي الكل يحاربه وهذا حال العراقيين بالعالم العربي لأننا بلد حضارة وهم بلد البعارة
# Score: 0.022884203121066093
#
#
# Text: طالما هيشتموها،،،  ليه مهتمين بيها وعامليين ليها حلقة ومديينها قيمة....
# ولا الناس؟؟؟؟ ليه اصلا متصلين...
# مش فاهمة حاجة خاااالص متناقضين..
# Score: 0.9710730314254761
#
#
# Text: عالم ناس تونسي اعترف بنات تونس اكبر قحاب العالم الاسلامي رحم ربي
# Score: 0.3524184226989746
#
#
# Text: المخير يشوفني يولي يرجف قلتها ونعودها تونسااا تحبو العهر
# Score: 0.8283678889274597
#
#
# Text: عيب عيب اخواتي التوانسا مخنثين يحسنون الكلام بالعربية بالفرنسية
# Score: 0.31867003440856934
#
#
# Text: ع شنو مغروره انتي لو حلوه مثل تفاحة العراق زهور علاء شسوين
# Score: 0.9537743926048279
#
#
# Text: الله يساعد زوجها تلقاه بيطبخ وبيمسح وبيغسل الملابس والله وبأخر الليل يغتصب من قبل المخلوق الوحشي المسمى أحلام 😋
# Score: 0.8959780335426331
#
#
# Text: الشخص اللي بيغير الجنس لذكر هيتسمى راجل برضه.
# Score: 0.8166300058364868
#
#
# Text: والله فنانات لاشكل ولا منظر ولا صوت بدون  مكياج تقرف تنظر لهم  ولا اى حد عجبهم  لا حول ولا قوة الا بالله
# Score: 0.9292141199111938
#
#
# Text: احلا تحيه لاحلام بس الناس مقهورين منها
# Score: 0.7390558123588562
#
#
# Text: سلام اين الادب اين الاخلاق كسيات عريات خشب جهنم ياويلك ياويلك الدنيا فنيا نش دايمة
# Score: 0.8135878443717957
#
#
# Text: لو كانت متعلمه ما كان هذا حالها نقطه لسطر
# Score: 0.3108518421649933
#
#
# Text: فعلا كلامك صح 100%
# للاسف ما حدا ماكلها غير هالشعب المعتر
# Score: 0.7945509552955627
#
#
# Text: احلام عفوية وطيبة واحسن من اي شخص وسخ بحكي عليها كلمة وسخة
# Score: 0.4518797993659973
#
#
# Text: شنو هالغرور الملكة ملكة على روحهة مو على الناس اموت منهة ومن الخليج كلة
# Score: 0.8998832106590271
#
#
# Text: ذكرى ما نسيناك وما حد بينسينا صوتك الجميل وطيبتك وقدراتك الغير موجوده في أي بشر رحمك الله
# Score: 0.5114110112190247
#
#
# Text: احلام عفويه واعتقد ان قلبها كثير طيب
# Score: 0.28535211086273193
#
#
# Text: اني عراقي وموت بحلام احسن مطربة بل خليجً وكلبهة طيب وعلى نياتهة
# Score: 0.60313481092453
#
#
# Text: ملكة انا بموت فيك وفشخصيتك القوية وفعفويتك ملكة ملكة
# Score: 0.5832989811897278
#
#
# Text: أحلام رووووووووعه بكل شي  احبببببببببببببببببببببك من كل قلبي
# Score: 0.7042117714881897
#
#
# Text: اللهم إني أسألك العفو والعافية في الدنيا والآخرة
# Score: 0.0
#
#
# Text: من لبنان تحية للملكة وفنانة العرب احلام
# Score: 0.018858248367905617
#
#
# Text: احلام كوني صامدا انا من الجزاير واشجعك لا تدعيهم يدمرونك
# Score: 0.0665505900979042
#
#
# Text: انتم على كلامكم هدا عن هذه المراة. تهدولها حسناتكم. على طبق اتقو لله وخليكم.من الغيبة. و فضح الناس
# Score: 0.1707664579153061
#
#
# Text: انا معك يا احلام ملكة الغناء الخليجي مافي اجمل من صوتك
# Score: 0.24414968490600586
#
#
# Text: بلعكس اني احبها لان هي ممأذيه احد وكولش صريحه
# Score: 0.2880191504955292
#
#
# Text: انا واخواتي وماما  مانتابع البرنامج الا عشان احلام بصراحه تضيف حماس وانفعالات وروح حلوه للبرناااامج 🎈🎈💝
# Score: 0.6803694367408752
#
#
# Text: قناة جميلة جداً وعجبتني الفكرة , لكن عندي ملاحظة بسيطة جداً غريبة كل الفيديوهات عن سيدات فقط ..!!!
# Score: 0.04293150454759598
#
#
# Text: انا بحب احلام بس  مو من حقها تحكي هيك على راغب علامة و هدا بس سوء تفاهم
# Score: 0.8783097863197327
#
#
# Text: كاظم الساهر القيصر العربي احسن مطرب عراقي وعربي وعالمي تحياتي إلى كاظم الساهر
# Score: 0.06243328005075455
#
#
# Text: كاظم الساهر هو من صنع نفسه بنفسه اشتهر بفضل صوته وإمكانياته وحسه الراقي الي ميزه عن باقي الفنانين .
# Score: 0.18199649453163147
#
#
# Text: عزيزي اوعزيزتي راجعي طبيب نفسي ربي يهدي الجميع وانا اول وحدة
# Score: 0.26179975271224976
#
#
# Text: يابه هذا مو عراقي هذا لبناني اسمه نينا ابو عباس
# Score: 0.8067746162414551
#
#
# ...
# Score: 0.7714741826057434
#
#
# Text:  ما راح تقنعنا انو نقول #ماغي_بو_غصن متفوقة انسى يا طبال
# بتظل #سيرين_عبد_النور هي الاولى واهم من المذكورين 🔥❤
# Score: 0.7412648797035217
#
#
# Text:  حقد الطبال لا مثيل له لن ينسى الرمز الراحل عندما مسح به الارض ماذا تتوقع من واحد طبال
# Score: 0.038463789969682693
#
#
# Text:   ابن عمك ووالده ما شاء الله مناصب عليا وأنت طقاقه في برنامج طبال ههههه سبحان اللي خلق وفرق
# Score: 0.5262832045555115
#
#
# Text:  هذولا انظف من كل فاسد نجس وانظف من كل طبال حقير يتكلّم بخشم الدينار  .هذولا رجال وليسوا أشباه الرجال
# Score: 0.5403048396110535
#
#
# Text:  هذا الي يقولك يقتل القتيل ويمشي في جنازته
# حسبي الله ونعم الوكيل فيك وفي كل ظالم و طبال
# Score: 0.4704520106315613
#
#
# Text:  نقول للمحسن أحسنت
# مش طبال ياطبل
# حرام ما تسوى ...... جنبه ،ماذكرت تعز إلا ذكرمعها وكان حاميها وحارب من أجل كرامتها
# Score: 0.49841001629829407
#
#
# Text:  هم هشكل اذا زعلت البنت عندهم يجيبون اسود تماسيح ضباع عادي الوضع هشكل عندهم عشان يحرم يزعلها مره ثانيه هذا اذا عاش اصلا 😂
# Score: 1.0
#
#
# Text:  فكرة حلوة بس اسا بدك مسؤول حديقة حيوانات فيها تماسيح و اسود و ضباع ، يخلّي قاصرة تشتغل عنده ؟
# حتى لو تطوّع ما بزبط🥲
# Score: 0.8150970339775085
#
#
# Text: بس تضحك وضحكتها فيها صدي ضباع وبعد قليل نقول سالفتها هي والاخت هيا شنو مسوين بطليقت زوج هيا 🙌 ياربي علي الظلم وشنو مسوين بفرس النهر ابتسام
# Score: 0.9781074523925781
#
#
# Text:  علشان هو بيفهم و عبقري😁😁 و احنا كجمهور امكانيات محدودة 😂😂😂
# يا استاذ محمد فيه حد يتكلم عن هذا الموسيماني في سوشيال ميديا الاهلي 🙄🤔
# Score: 0.7932175993919373
#
#
# Text: لا تهجموا ولا شي اللي لابسة مب حق المثليين ذا قوس قزح لازم تفرقون هذي ٧ الوان و المثليين ٦ الوان🤡
# Score: 0.7945427298545837
#
#
# Text:  صحيح ان لابيد هو يهودي من قماش نتنياهو الا أنه أقل تطرفا وأكثر مرونة أمام مطالبنا فبالطبع سأصوت له.
# Score: 0.019886108115315437
#
#
# Text:  كما عهدنا حضورك دائما أ.شوقي .. نجدك في الجوانب الخدمية والمشاريع المستدامة والتي من شأنها تحسين الوضع المعيشي.
# Score: 0.0
#
#
# Text: تم فصل محطة زاباروجيا النووية الأوكرانية  تماما عن شبكة الطاقة الأوكرانية لأول مرة
# وبدات روسيا لعبة كسر العظام ...
# Score: 0.0
#
#
# Text: #روسيا | ماريا زاخاروفا: محطات توليد الطاقة النووية في أوكرانيا تعمل بشكل طبيعي، ولم يلحق بها أي ضرر.
# #غرب_آسيا
# Score: 0.0
#
#
# Text: 🔴#عاجل| وزيرة الخارجية الألمانية: إيران رفضت الإيفاء بالتزاماتها تجاه وكالة الطاقة الذرية ومنعت المفتشين من دخول المنشآت النووية
# #TeNTV
# Score: 0.0
#
#
# Text: ⚡️المتحدث باسم منظمة الطاقة الذرية الإيرانية: نتفاوض مع روسيا لتطوير المرحلتين الثانية والثالثة من محطة بوشهر النووية.
# #روسيا #إيران
# Score: 0.0
#
#
# Text: رئيس هيئة الطاقة الذرية الإيرانية: في التاسع من أبريل، ستكشف #إيران عن الوثيقة الشاملة حول التطوير الاستراتيجي للصناعة النووية.
# Score: 0.0
#
#
# Text:  ماهي دي الصناعات الملوثه للبيئه..ورغم ذلك يوجد عجز في الاسمده وأسعارها مرتفعه كذا أسعار الأسمنت والألمنيوم.
# Score: 0.38994261622428894
#
#
# Text:  شركة المطلق للاستيراد من #الصين يمكنها توفير جميع خطوط الانتاج لدعم الصناعات السعودية في شتى المجالات.
# Score: 0.0
#
#
# Text:  ومع التطورات الجديدة يدخل الروبوت عالم الخدمات المنزلية والتجارية والطبية بعدما دخل عالم الصناعات الثقيلة والدقيقة.
# Score: 0.0
#
#
# Text:  اتمنى من وزير التجاره ان يعمد الشركات  خاصه لكزز البيع الاولويه للافراد حسب حجوزاتهم لا لتجار الاحتكار بعضهم له اكثر من سته شهور
# Score: 0.0
#
#
# Text:  #مساجدنا_على_الطرق  جمعية أهلية تسعى إلى العناية المستدامة بمساجدنا على الطرق تجهيزاً وصيانة وفق شراكات متميزة وفعالة
# Score: 0.0
#
#
# Text: ومنح القضايا البيئية طابعًا إنسانيًّا من خلال تمكين المُجتمعات المحلِّية من أنْ تصبح عوامل نشطة لتحقيق التنمية العادلة المستدامة،
# Score: 0.0
#
#
# Text:  مساء الخير يا أخ عبدالله ، هل يمكنكم الحديث عن الزراعة المنزلية ( زراعة الأسطح ) المراكن ✋🏻
# Score: 0.0
#
#
# Text:  تشكل استراتيجية الأمن الغذائي استجابة مباشرة للحاجة الملحة والأولوية المعطاه للأمن الغذائي على أعلى المستويات في الأردن 🇯🇴🇯🇴
# Score: 0.0
#
#
# Text: يجب انصاف المحاضرين والاداريين المشمولين بقرار ١٣٠ وتحويلهم على قرار مجلس الوزراء ٣١٥ ضمن قانون الأمن الغذائي
# Score: 0.0
#
#
# Text: المجلس البلدي يرفض طلب الهيئة العامة للزراعة في شأن تخصيص موقع لتربية الأبل لدعم مشروع الأمن الغذائي وتنمية الثروة الحيوانية.
# Score: 0.0
#
#
# Text: الجمهورية الإسلامية الإيرانية هي الأخرى مثال واضح على الإصرار والكرامة الوطنية لامتلاك حق استخدام الطاقة النووية للاستخدام السلمي.
# Score: 0.0
#
#
# Text: رئيس الاحتياطي الفدرالي #باول: هناك احتمال لأن يبقى التضخم مرتفعا لفترة أطول من المتوقع، وهدفنا هو إعادة التضخم إلى 2 بالمئة
#
# #عاجل #اقتصاد
# Score: 0.0
#
#
# Text:   التضخم والبنك المركزي لا ينقص مصر اي سلعه تودي الي التضخم.  والبنك المركزي. هي لا تعرف كم نسبه الاستثمار بمصر
# Score: 0.0
#
#
# Text:  اللي فهمته
# ان كل سنه بناء على معدل التضخم فى السنة يتم زيادة المعاش بقيمة معدل التضخم او اكثر حسب ميزانية الدولة
# Score: 0.33124643564224243
#
#
# Text:  هل التضخم بأمريكا ينزل ام يصعد... و ما هو سيناريو الفيديرالي الأمريكي في حال نزل التضخم هل سيتواصل رفع الفائدة..... افيدونا
# Score: 0.0038080806843936443
#
#
# Text: وكما توقعت قبل اشهر سيصل التضخم محلياً الى اكثر من 3% على أساس سنوي، أي ضعف التضخم الذي سُجل في 2021 والذي وصل الى 1.6%
# Score: 0.0
#
#
# Text: بنظري الانتظار لحد ١٧ الشهر لنشوف رفع الفائدة ٧٥ فاد علي التضخم هل سوف ينزل التضخم من ٨.٣ لحد ٧.٥ ام لا هنا يبقا السوال
# Score: 0.5298579335212708
#
#
# Text: 📊📉 ارتفع معدل التضخم السنوي في #تركيا إلى 61% في مارس ، وهو الأعلى في عقدين.
# Score: 0.0
#
#
# Text:  هذا سوف يؤدي الي رفع سعر الخمور في السوق السوداء و في مصلحة التجار في السوق السوداء
# Score: 0.0
#
#
# Text: بمناسبة الحر النهاردة  ، هل تتوقعوا ان العالم يبدأ يفوق و يحل مشكلة الاحتباس الحراري قبل فوات الأوان و لا هنفوق بعد خراب مالطة؟
# Score: 0.5468764305114746
#
#
# Text:   يعني الابل تسبب غبار والبقر سبب الاحتباس الحراري هذا اخر ما توصل له العلماء نتخلص من الحيوانات وناكل لحوم من المختبرات
# Score: 0.20164629817008972
#
#
# Text: الأجهزة الحديثة للتحليل الوزني الحراري تكون متصلة بحاسوب يحدد أعلى درجة حرارة للتحليل، كما ينظم معدل التسخين ومعدل تمرير الغاز.
# Score: 0.0
#
#
# Text: الحمدالله كان يوم جميل غائم ممطر مع دوى الرعود في بعض أحياء المدينة الحمل الحراري ساعد على بناء السحب بعد مافتقدناه الأسابيع الماضية
# Score: 0.021184151992201805
#
#
# Text: عاجل | رئيسة المفوضية الأوروبية: بوتين يواصل ابتزاز أوروبا ولكننا سنتصدى لذلك بتعزيز اعتمادنا على الطاقة المتجددة
# Score: 0.0
#
#
# Text:  و السماعة ديه بتكشف بيها على البطاريات الليثيوم؟ و لا بتولد بيها الطاقة المتجددة .. يا ....
# Score: 0.7959677577018738
#
#
# Text: عاجل | رويترز: وزير الطاقة الأوكراني يقول إن محطات الطاقة تعمل بشكل مستقر
# #الحرب_الروسية_الأوكرانية #مباشر_أوكرانيا 🇺🇦
# Score: 0.0
#
#
# Text: رئيس هيئة الطاقة الذرية الإيرانية: سنعلن السبت وثيقة استراتيجية لتنمية الصناعات النووية تحدد رؤيتنا لـ 20 عاما
# Score: 0.0
#
#
# Text: القناة الفرنسية: فرنسا تعاني من نقص الطاقة سيبدأ بناء جيل جديد من المفاعلات النووية قبل عام 2027.
# Score: 0.01638825051486492
#
#
# Text:   الله يسهل اموركم وإن شاء الله الوزارة تتحرك لما يخدمكم وزراعتكم اللي تعتبر من الأمن الغذائي للمملكة حفظها الله
# Score: 0.3500921130180359
#
#
# Text: هل فيه وعي عند الشعب بنسبة الهدر الغذائي في شهر رمضان؟
#
# ليش مانشوف برامج توعويه بخصوص الهدر الغذائي.
# Score: 0.5554271340370178
#
#
# Text:  تعديل الاجور بمقدار التضخم يسبب بقاء الاسعار على ما هي عليه، اي يصبح التضخم جزاء من الاقتصاد.
# Score: 0.0
#
#
# Text:   و الثلج تحطه بابريق القهوه اول بعدين فوق القمع وورق الترشيح صح؟ يعني تصير القهوه تنزل على الثلج
# Score: 1.0
#
#
# Text: شكراً لجهاز الرقابة على التجاوب والتدخل أحسنتم وبارك الله جهودكم...بكم ستكون عمان بألف خير وعلى رأسكم جلالة السلطان المعظم
# Score: 0.0
#
#
# Text:  من مهام المدقق تقييم نظام الرقابة الداخلية.. وفي حال وجود مشكلة في تصميمه فمن حقه كتابة الملاحظة دون وجود مستند
# Score: 0.0
#
#
# Text: #السودان السفارة الأمريكية بالخرطوم تشجب الهجمات العنيفة التي تشنها أجهزة الأمن السودانية على وسائل الإعلام والصحفيين .
# Score: 0.0
#
#
# Text: رويترز - الإمارات تستدعي وتعتقل عدة أشخاص لنشرهم مقاطع فيديو تظهر الهجمات الصاروخية التي تعرضت لها أبوظبي
# Score: 0.0
#
#
# Text: #عاجل …..|
#
# رسميًا … لن يرتدي أي لاعب شارة المثليين في المونديال . . .
#
# #FIFAWorldCup
# Score: 0.0
#
#
# Text: #الإعلام_العبري | "القناة 12" العبرية: إستمر الإجتماع الذي جمع ليلة أمس نتنياهو وياري ليفين وسموتريتش حتى الساعة 2 فجراً.
# Score: 0.0
#
#
# Text: عاجل | زعيم حزب الليكود المعارض بنيامين نتنياهو يتوعد بإلغاء اتفاق ترسيم الحدود البحرية مع #لبنان في حال فوزه.
# Score: 0.0
#
#
# Text: نتنياهو: في الأول من شهر تشرين الثاني "نوفمبر" ستتحول إسرائيل من الدفاع إلى الهجوم ضد إيران وبرنامجها النووي
# Score: 0.0
#
#
# Text: بي بي سي عاجل: عينات تلفزيونية أولية لنتائج الانتخابات الإسرائيلية تظهر تقدم تحالف أقصى اليمين بقيادة بنيامين نتنياهو
# Score: 0.0
#
#
# Text: عاجل | #نتنياهو بعد لقائه رئيس الوزراء الإسرائيلي: قدمت نصائح من خلال تجربتي وأقدم الدعم الكامل للحكومة والجيش وقوات الأمن الإسرائيلية
# Score: 0.0
#
#
# Text: #عاجل | الرئيس الأمريكي: صادقت على قانون لتخفيض التضخم، وقانون الحد من التضخم هو الأكبر في تاريخ الولايات المتحدة
#
# #صحيفة_الخليج
# Score: 0.0
#
#
# Text: #عاجل |
# مصادر ميدانية تتحدث عن انتفاضة قبلية داخل مديرية بيحان بشبوة ضد تواجد "ميليشيات الحوثيين"
# Score: 0.0
#
#
# Text: بالرغم من أن سؤال الاستعمار الاستيطاني قد لا يكون معترفاً به ضمنياً، فإنه يجب أن يُستعاد ويُسلط الضوء عليه.
# Score: 0.0
#
#
# Text: مع تدهور الوضع الاقتصادي وتزايد التضييقات الأمنية، يواجه المصريون، معاناة إضافية تتعلق بالقدرة على توفير سبل العيش، والحياة بأمان
# Score: 0.0
#
#
# Text: سوريا امنة ان شاء الله برا وبحرا وجوا بهمة هدول هالاسود
# Score: 0.5614315867424011
#
#
# Text:  هآرتس: حماس تستعيد قوتها بسرعة وعمليات الجيش الإسرائيلي في غزة تتعثّر
# Score: 0.0
#
#
# Text: مدير مكتب الميادين في فلسطين: هناك تحسب إسرائيلي من اندلاع انتفاضة في المدن المختلطة داخل أراضي الـ48
# Score: 0.004985451232641935
#
#
# Text: صحيح هذا قوات افرزتها حرب ٩٤ وهي قوات احتلال   ويجب إنهاء الاحتلال لأجل تستمر الوحده  لاتوجد وحده بوجود احتلال
# Score: 0.0
#
#
# Text:  صح الكل والمفروض بالدراسه ندرسها كلها اهم يدرسون حقنا واحنا ندرس حقهم والمفروض يفهمون ان كل المذاهب صحيحه والكل لازم يحترم الثاني
# Score: 0.8041906952857971
#
#
# Text: نحن أهل فلسطين، ونحن أصلنا فلسطين، وروحنا فلسطين، وثقافتنا فلسطين، وهدفنا العودة إلى فلسطين #لا_لنکبة_التطبيع #يوم_النكبة
# Score: 0.0
#
#
# Text: نستودعك اللهم تراب فلسطين وهواء فلسطين وماء فلسطين وشعب فلسطين انصرهم وكن لهم معينا واشدد أزرهم يالله #لن_يمر_الاقتحام
# Score: 0.0
#
#
# Text: 🇵🇸
# مرحاف عزه:
# أكثر من 115 صاروخا أطلق من غزة نحو مستوطنات الغلاف منذ بدء العملية.
# Score: 0.04293714463710785
#
#
# Text: قواعد التعامل مع الشدائد القاعدة الخامسة (اعرف حقيقة الدنيا تسترح) القاعدة السادسة (أحسن الظن بربك) 🌿
# Score: 0.0
#
#
# Text: عاجل | الإمارات: إدراج فرد و5 كيانات إرهابية ضمن قائمة الإرهاب يهدف لتعطيل الشبكة المرتبطة بتمويل الإرهاب والنشاطات المصاحبة له
# Score: 0.0
#
#
# Text:  لا تنسى انها عضو اساسي في الناتو ولو قرر الناتو مهاجمة روسية بشكل رسمي لن تستطيع تركيا الاعتذار
# Score: 0.00869503989815712
#
#
# Text:  نقدر جهودكم المبذولة في مكافحة التطرف وتكثيف الجهود لنشر افكار التسامح و السلام موفقين باذن الله
# Score: 0.0
#
#
# Text: عاجل | المستشار الدبلوماسي لرئيس دولة الإمارات: منهج الإمارات الذي يركز على التسامح ورفض التطرف والعنف يثبت باستمرار قوته وصوابه
# Score: 0.0
#
#
# Text: اليمن في قلب المعركة والشرق الأوسط يقترب من الانفجار الكبير!
# Score: 0.0
#
#
# Text: الناطق بإسم جيش الإحتلال الإسرائيلي:
#  اطلاق صاروخ واحد من اليمن نحو إسرائيل ليتم اعتراضه قبل ان يخترق المجال الجوي الاسرائيلي
#
# #عاجل
# Score: 0.0
#
#
# Text:  بارك الله فيك واصطبر على ما ستقرؤه ممن امتلأت قلوبهم بالطائفية المقيتة مع أن الشيخ قالها صريحة المذاهب معرفات والإسلام هو الأصل .
# Score: 0.0
#
#
# Text:  اثرت كثير، بطريقة اوجه صرف الاموال والحفاظ عليها وتنميتها ووضع موازنة للمصروفات الاستهلاكيه وموازنة للمصروفات الرأسمالية.
# Score: 0.011018205434083939
#
#
# Text: الجزائر: الرئيس الجزائري عبد المجيد تبون: الجزائر قررت إلغاء كل فوائد الديون الممنوحة لكوبا وتأجيل استيفاء الديون من هافانا
# Score: 0.037364110350608826
#
#
# Text: #متابعات | #دولي
#
# 🔰صندوق النقد الدولي : حالة الاقتصاد العالمي هي الأسوأ منذ الحرب العالمية الثانية.
# Score: 0.0
#
#
# Text: صندوق النقد الدولي : نطالب دول العالم لاسيما الغنية بالكف عن تخزين الغذاء وتجنب القيود على التجارة .
# Score: 0.0
#
#
# Text: #صندوق النقد الدولي :
#
# اقتصاد المملكة العربية السعودية سيتخطى تريليون دولار في 2022 لأول مرة في تاريخه🇸🇦❤️.
# Score: 0.0
#
#
# Text: #تحديث
#
# الزعيم بوتين 🇷🇺 : الولايات المتحدة قد تسرق احتياطات دول العالم من الأموال في صندوق النقد الدولي
# Score: 0.0
#
#
# Text: العربية نقلاً عن الاتحاد الأوروبي: سنعمل على تعليق عضوية روسيا في صندوق النقد والبنك الدوليين  #ليبانون_ديبايت
# Score: 0.0
#
#
# Text:  ليش نعتمد على توقع صندوق النقد الدولي ،، لماذا لا نعتمد على الاحصاءات الرسمية ل وزارة المالية .
# Score: 0.2878921627998352
#
#
# Text: وزير الخارجية عبد الله بوحبيب: المطلوب من مجلس النواب إقرار القوانين التي أحالتها الحكومة والتي يريدها صندوق النقد
# Score: 0.0
#
#
# Text:  اسمح لي أستاذ فارس وأنا لست من الفقهاء ولا أتدخل في الأديان ولا المذاهب الاخرى وامنياتي أن يعيش الجميع في أمن وسلام
# Score: 0.0
#
#
# Text: مصادر لـ"الشرق": صندوق النقد الدولي يطالب #مصر بتوحيد أسعار فائدة القروض، وإلغاء كل المبادرات ذات الفائدة المنخفضة
# Score: 0.0
#
#
# Text: وزير الصحة: المفاوضات مع صندوق النقد في مرحلة متقدمة ولا دعم للدواء المستورد الذي له بديل محلي
# #الديار #لبنان
# Score: 0.0
#
#
# Text:  لأن سوريا قبل الحرب كانت الدولة الوحيدة التي ليس لديها ديون خارجية ولا ديون من صندوق النقد الدولي
# Score: 0.0
#
#
# Text: عاجل | متحدث باسم صندوق النقد الدولي يقول إن الصندوق عين ممثلا مقيما في #لبنان وسيواصل المحادثات بشأن برنامج إصلاح اقتصادي
# Score: 0.0
#
#
# Text: بري: اثمن  هذا الانجاز و نقدر الجهود التي بذلت من جانب فريق صندوق النقد الدولي للتوصل له والذي يشكل  بداية عودة لبنان الى سكة التعافي
# Score: 0.0
#
#
# Text: لا إبداع بدون الحرية، وهي تشمل الجانب الفكري والجسدي. أنظمة الاستبداد على صعيد الدولة أو المجتمع لا تنتج سوى الإنسان "المقهور المهدور".
# Score: 0.0
#
#
# Text: في سعينا للحصول على الثروة ؛ أضعنا مقدراتنا الكبيرة
# لنكتشف بعد مرور الوقت بأن ما نملكه سابقاً كان هو الثروة الحقيقيّة
# Score: 0.0
#
#
# Text:   عائدات الضرائب لو ماكانت للقوات المسلحه لمن بتكون؟ الدول الكبرى تفق على جيشها وحكومتاها من الضرائب
# Score: 0.49825355410575867
#
#
# Text: ما نتيجة قضية رشوة وزارة الصحة  هل تم إجازة فتح مستشفى دار الصحة محل قضية الرشوة أم مازالت المستشفى مغلقة رسميا لعدم الصلاحية
# Score: 0.0
#
#
# Text: يا من يذكرني بعهد أحبتي طاب الحديث بذكرهم ويطيب أعد الحديث علي من جنباته إن الحديث عن الحبيب حبيب   ابن زهر الحفيد✨🌿
# Score: 0.013303667306900024
#
#
# Text:     طيب انتي قلتي في قتل المرتد فيه تعارض بين الحديث والقران ممكن تبيني لي وجه التعارض؟؟
# Score: 0.4507030248641968
#
#
# Text:  للأسف أصبح التكفير سهل جدًا لدى البعض، أي شخص مختلف عنه مباشرة يقوم بتكفيره وكأنه هو وحده على حق.
# نسأل الله السلامة.
# Score: 0.006447700317949057
#
#
# Text:  شتانا بين من يروج للدين بالعنف و التكفير و بين من يروج له بالحسنه و المنطق و الفهم الصحيح للاسلام .بركت دكتور عبد الحكيم .
# Score: 0.028079276904463768
#
#
# Text:  لازم يعرف المسلم ان التكفير امره عظيم كانك تحكم على العبد بدلا من الله في حكم الله وفي حق الله. يجب اي يعي المكفر ذلك.
# Score: 0.0992337241768837
#
#
# Text: وقد بلغت ذروتها بعد أن قتلت الكنيسة أربعة من العلماء الذين كانوا أعضاءً في تلك الجمعية، وتعهدت الجمعية أن تأخذ بالثأر من الكنيسة.
# Score: 0.0
#
#
# Text: الف رحمه ونور علي شهداء الكنيسة وعزاء واجب مخلص لاهلهم جميعا ويارب الصبر والسلوان لجميع المصريين .🤲
# Score: 0.1574304699897766
#
#
# Text: طارق عزيز مواليد 1936 انصح هذا الجيل بالقراءة عنه شخصيته عجيبة مثيرة يجمع بين الاصولية المسيحية والاسلام وحمل السلاح
# Score: 0.0
#
#
# Text: إن الله وزّع الأرزاق بالعدل، ولم يوزعها بالتساوي؛ لإن العدل مبدأ أسمى من المساواة.
#
# -أدهم شرقاوي
# Score: 0.009707087650895119
#
#
# Text: "المساواة تتم في إطار المرجعية المتجاوزة والإيمان بأن الإنسان مقولة مستقلة عن عالم المادة رغم وجودة فيها"
# Score: 0.0
#
#
# Text:  سمعت قبل كدة ان المثلية كانت محرمة ف مصر القديمة لكن مش متأكدة من المعلومة بصراحة
# Score: 0.6269225478172302
#
#
# Text: في 19 أغسطس 2020، أقر مجلس الأمة الكويتي مشروع قانون الحماية من العنف الأسري وإحالته إلى الحكومة.
# #سايسها_لا_تعنفها
# Score: 0.0
#
#
# Text:   البطالة أولًا وأخيرًا، لو وجدوا لها حلًا فستنتهي كل الأسباب الأخرى سواء الفقر أو المخدرات أو العنف الأسري.
# Score: 0.0
#
#
# Text:  أختلف مع حضرتك ، العنف الأسري ده بداية كل حاجة غلط
# و اصلا مش من شيم الرجولة ولا المروءة ، أختلف مع حضرتك تماما
# Score: 0.4683280289173126
#
#
# Text:  سؤال
# الاغتصاب
# والعلاقة الغير شرعية برضى الطرفين
# الاتنين ديل يعتبرو نفس الشي زنا وحكمه جلد او رجم؟
# Score: 0.22667627036571503
#
#
# Text: تحت عنوان:
# "الاغتصاب في سجون الأسد".. جحيم لم يستثن المسنات (تفاصيل وشهادات)
# وثقتها جريدة زمان الوصل منذ فترة ⬇️
#
# #بدنا_المعتقلين
# Score: 0.031234607100486755
#
#
# Text:  مااتوقع ان الخبر صحيح فيه لبس في الموضوع
# ليس نزاهه في قضاتهم وإنما يمكن فيه اعتدا غير الاغتصاب
# Score: 0.3394656777381897

# %%
from sklearn.linear_model import LogisticRegression

X = train_df_1[["ALDi_score"]].values
y = train_df_1["polarization"].values

clf = LogisticRegression()
clf.fit(X, y)

coef = clf.coef_[0][0]
intercept = clf.intercept_[0]

print("coef:", coef)
print("intercept:", intercept)

aldi_grid = np.linspace(X.min(), X.max(), 100).reshape(-1, 1)
probs = clf.predict_proba(aldi_grid)[:, 1]

fig, axes = plt.subplots(1, 3, figsize=(16, 5))

# New first fig: Histogram of ALDi scores
axes[0].hist(train_df_1["ALDi_score"], bins=30, color="skyblue", edgecolor="black")
axes[0].set_title("Histogram of ALDi Scores")
axes[0].set_xlabel("ALDi_score")
axes[0].set_ylabel("Frequency")

# Second fig: Boxplot as in @file_context_0
train_df_1.boxplot(column="ALDi_score", by="polarization", ax=axes[1])
axes[1].set_title("ALDi_score by polarization")
axes[1].set_xlabel("polarization")
axes[1].set_ylabel("ALDi_score")
plt.suptitle("")

# Third fig: Logistic regression probability curve
axes[2].plot(aldi_grid, probs)
axes[2].set_xlabel("ALDi_score")
axes[2].set_ylabel("P(polarization = 1)")
axes[2].set_title("ALDi Scores and Polarization")
axes[2].set_ylim(0, 1)

plt.tight_layout()
plt.show()
# Out:
# coef: 1.4077098306040705
# intercept: -0.7158446584919996

# %% [markdown]
# ## NADI

# %%
DIALECTS = [
    "Algeria",
    "Bahrain",
    "Egypt",
    "Iraq",
    "Jordan",
    "Kuwait",
    "Lebanon",
    "Libya",
    "Morocco",
    "Oman",
    "Palestine",
    "Qatar",
    "Saudi_Arabia",
    "Sudan",
    "Syria",
    "Tunisia",
    "UAE",
    "Yemen",
]
DIALECT_to_region = {
    "Algeria": "Maghrebi",
    "Libya": "Maghrebi",
    "Morocco": "Maghrebi",
    "Tunisia": "Maghrebi",
    "Egypt": "Egyptian",
    "Iraq": "Iraqi",
    "Jordan": "Levantine",
    "Lebanon": "Levantine",
    "Palestine": "Levantine",
    "Syria": "Levantine",
    "Bahrain": "Gulf",
    "Kuwait": "Gulf",
    "Oman": "Gulf",
    "Qatar": "Gulf",
    "Saudi_Arabia": "Gulf",
    "UAE": "Gulf",
    "Yemen": "Gulf",
    "Sudan": "Sudan"
}
assert len(DIALECTS) == 18

MODEL_NAME = "AMR-KELEG/NADI2024-baseline"

tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
model = AutoModelForSequenceClassification.from_pretrained(MODEL_NAME).to(device)

def predict_nadi(text, verbose=False):
    inputs = tokenizer(text, return_tensors="pt")
    inputs = {k: v.to(device) for k, v in inputs.items()}

    with torch.no_grad():
        logits = model(**inputs).logits

    probs = torch.softmax(logits, dim=1).flatten()

    region_scores = {}
    for i, p in enumerate(probs):
        dialect = DIALECTS[i]
        region = DIALECT_to_region[dialect]
        prob = p.item()
        # keep the max probability per region
        if region not in region_scores or prob > region_scores[region]:
            region_scores[region] = prob

    return region_scores

# %%
import torch
train_df_1["nadi"] = [
    predict_nadi(x)
    for x in tqdm(train_df_1["text"], total=len(train_df_1), desc="Predicting nadi")
]
# extract actual predicted value for each region to new columns
train_df_1["Gulf"] = train_df_1["nadi"].apply(lambda x: x.get("Gulf", 0))
train_df_1["Egyptian"] = train_df_1["nadi"].apply(lambda x: x.get("Egyptian", 0))
train_df_1["Levantine"] = train_df_1["nadi"].apply(lambda x: x.get("Levantine", 0))
train_df_1["Iraqi"] = train_df_1["nadi"].apply(lambda x: x.get("Iraqi", 0))
train_df_1["Maghrebi"] = train_df_1["nadi"].apply(lambda x: x.get("Maghrebi", 0))
train_df_1["Sudan"] = train_df_1["nadi"].apply(lambda x: x.get("Sudan", 0))
# drop train_df_1["nadi"] column
train_df_1 = train_df_1.drop(columns=["nadi"])
# Out:
# Predicting nadi:   0%|          | 0/3380 [00:00<?, ?it/s]

# %%
dialect_cols = list(set(DIALECT_to_region.values()))
correlations = train_df_1[dialect_cols].corrwith(train_df_1['polarization'])

# Plot
plt.figure(figsize=(10, 6))
correlations.sort_values().plot(kind='barh', color='teal')
plt.axvline(0, color='black', linewidth=0.8)
plt.title("Correlation: Higher Dialect Score vs. Polarization")
plt.xlabel("Correlation Coefficient (Pearson)")
plt.show()

# %%
threshold_nadi = 0.4 # adjust as you like
threshold_aldi = 0.4 # adjust as you like

polarization_percentages = []

for region in dialect_cols:
    mask = train_df_1[region] >= threshold_nadi
    # mask also if aldi >= 0.5 only
    mask = mask & (train_df_1["ALDi_score"] >= threshold_aldi)
    n_region = mask.sum()
    if n_region == 0:
        pct = 0.0
    else:
        pct = 100 * train_df_1.loc[mask, "polarization"].mean()
    polarization_percentages.append(pct)

plt.figure(figsize=(10, 6))
plt.bar(dialect_cols, polarization_percentages)
plt.ylabel("Percentage of Polarized Texts")
plt.title(f"Percentage of Polarized Texts per Region")
plt.ylim(0, 100)
plt.show()
